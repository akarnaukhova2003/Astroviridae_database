# %%
import os
from Bio import SeqIO, Entrez
import pandas as pd
import csv
import argparse
import copy
import re

# %%
'''
Downloads entries from GenBank Nucleotide by given query
Saves entries to file in GenBank format
Input:
    query - str - query for search in GenBank
Output:
    outfile - str - shortname of output file with sequences in genbank format
'''
def fetch_seq_from_Nucleotide(query, outfile):

    Entrez.email = "A.N.Other@example.com"
    # list with ids obtained by query
    record = Entrez.read(Entrez.esearch(db="nucleotide", term=query, idtype="acc", RetMax=1000000))
    id_list = record['IdList']
    print("Query to GenBank Nucleotide database:\"{}\"".format(query))
    print("Number of records found: {}".format(record["Count"]))
    print("{} records will be downloaded".format(len(id_list)))
    # output file with sequences will be saved in current working dir
    f_name = os.path.abspath(outfile)

    # output file with sequences in fasta format
    file_out = open(f_name, 'w')
    
    # Saving sequences 
    
    i = 0
    # fetch each sequence from GenBank by its ID and writes to ouput file
    for id in id_list:
        i+=1
        if i % 500 ==0:
            print("Downloaded {} sequences".format(i))
        handle = Entrez.efetch(db="nucleotide", id=id, rettype="genbank", retmode="text")
        for line in handle:
            file_out.write(line)
        handle.close()
    file_out.close()
    print('Finished')
    return(f_name)

# %%
def fetch_metadata_from_gb(input_file):
    '''
    For each entry in GenBank file retrieves the following data:

    # Identifiers
    Accession
    GenBank title (DEFINITION)

    # Classification
    Organism name
    Species
    Isolate
    Strain
    Family
    Lineage

    #Sequence quality
    Length
    Strand

    Num of annotated CDS

    ORF1a
    ORF1b
    ORF2
    coords
    
    #Sources
    Country
    Tissue/Specimen/Source
    Collection date
    Release date
    Submitters
    
    '''

    '''
     dictionary
     entries_data[GenBank Accession] = {}
     entries_data[GenBank Accession].keys() = [
                                                'Version',
                                                'GenBank title'
                                                'Organism name',
                                                'Species',
                                                'Family',
                                                'Virus Lineage',
                                                'Length',
                                                'Isolate',
                                                'Strain',
                                                'Strand',
                                                'Geo location'
                                                'Country',
                                                'Tissue/Specimen/Source',
                                                'Host',
                                                'Collection date',
                                                'Release date',
                                                'Submitters',
                                                'Sequencing Technology'
                                                'CDS number',
                                                'Artificial',
                                                'UNVERIFIED'
                                                ]
    '''
    entries_data = {}

    source_qualifiers = ["strain", "isolate", "geo_loc_name", "country", "collection_date", "isolation_source", "host"]
    source_qualifiers_columns = ["Strain", "Isolate", "Geo location", "Country", "Collection date", "Tissue/Specimen/Source", "Host"]

    entries = SeqIO.parse(os.path.abspath(input_file), "genbank")

    for entry in entries:
        entries_data[entry.name] = {}
        entries_data[entry.name]['Version'] = entry.id
        entries_data[entry.name]['GenBank title'] = entry.description

        entries_data[entry.name]['Release date'] = entry.annotations['date']
        entries_data[entry.name]['Organism name'] = entry.annotations['organism']
        
        entries_data[entry.name]['Virus Lineage'] = ';'.join(entry.annotations['taxonomy'])
        num_taxa = len(entry.annotations['taxonomy'])
        if num_taxa == 9:
            entries_data[entry.name]['Species'] = entry.annotations['taxonomy'][-1]
        else:
             entries_data[entry.name]['Species'] = 'NA'
        entries_data[entry.name]['Family'] = entry.annotations['taxonomy'][6]
        
        entries_data[entry.name]['Length'] = len(entry)

        for reference in entry.annotations['references']:
            if reference.title == 'Direct Submission':
                entries_data[entry.name]['Submitters'] = reference.authors

        count_cds = 0
        for feature in entry.features:
            if feature.type == 'source':
                for qualif, colname in zip(source_qualifiers, source_qualifiers_columns):
                    if qualif in feature.qualifiers:
                        entries_data[entry.name][colname] = feature.qualifiers[qualif][0]
                    else:
                        entries_data[entry.name][colname] = 'NA'
                if 'environmental_sample' in feature.qualifiers:
                    entries_data[entry.name]['Environmental'] = 'Yes'
                else:
                    entries_data[entry.name]['Environmental'] = 'No'
                    
            if feature.type == 'CDS':
                
                count_cds +=1
                
        entries_data[entry.name]['CDS count'] = count_cds


        artificial_condition1 = ("patent" in entry.description.lower()) or ("oligonucleotide" in entry.description.lower())
        artificial_condition2 = "crispr" in entry.description.lower()
        artificial_condition3 = "method" in entry.description.lower()
        artificial_condition4 = ("modified microbial nucleic acid" in entry.description.lower()) or ("nonfunctional" in entry.description.lower())

        
        
        if artificial_condition1 or artificial_condition2 or artificial_condition3 or artificial_condition4:
            entries_data[entry.name]['Artificial'] = "Yes"
        else:
            entries_data[entry.name]['Artificial'] = "No"


        if 'UNVERIFIED' in entry.description:
            entries_data[entry.name]['UNVERIFIED'] = "Yes"
        else:
            entries_data[entry.name]['UNVERIFIED'] = "No"

    meta_dataframe = pd.DataFrame.from_dict(entries_data, orient='index')
    
    meta_dataframe.to_csv(os.path.splitext(os.path.abspath(input_file))[0] + '.csv')
    #country_map - file with abbreviations of countries
    return meta_dataframe

# %%
#custom csv parser 
def read_csv(file_name, strip_it=True):
    if not os.path.exists(file_name):
        return {}

    def strip(value):
        return strip_it and value.strip() or value

    with open(file_name) as csvfile:
        reader = csv.DictReader(csvfile,
                                delimiter=",", 
                                fieldnames=["base", "new"])
        result = {}
        for row in reader:

            result[strip(row["base"])] = strip(row["new"])
        csvfile.close()
        return result

def map_feature(feature, feature_map):
    '''
    feature_map - dictionary, e.g. feature_map['Italia']='ITA'
    feature - possible key from feature_map
    return value if key is in feature_map
    '''
    for k, v in feature_map.items():
        if feature.lower() == k.lower():
            return v
    return feature


def map_keywords(stri, keywords_dict):
    '''
    stri - GenBank DEFINITION, string
    keywords_dict - dictionary with keywords that can indicate which ORF is covered  by the sequence
    return list of unique ORF codes if the corresponding keywords werencountered in DEFINITION
    '''
    codes = []
    for word, code in keywords_dict.items():
        if word.lower() in stri.lower():
            codes.append(code)
    codes = list(set(codes))
    return codes

    
def orf_coord(input_file, orf_map):
    '''
    Retrieves the coordinates of ORFs
    
    Input:
        input_file - file with nucleotide sequences in genbank-format
        orf_map - csv file annotation of orfs and their codes
    Output:
        coord_file - file with coordinates
    '''

    # dictionary with possiple names of astrovirus ORFs indicated in note, gene and product qualifiers
    # orf_dict["ORF1a"] = "1A"
    orf_dict = read_csv(orf_map)

    # ORFs which coordinates this script will extract
    orf_types_final = ['1A', '1B', '2']
    # ORFs that can be met
    orf_types = ['1A', '1B', '1AB', '2']

    # name of output file with ORF coordinates
    out_file_name_temp = os.path.splitext(os.path.abspath(input_file))[0]
    out_file_name = out_file_name_temp  + '_orf-coords.csv'
    print(out_file_name)

    # Keywords in description that can indicate which ORF is covered  by the sequence
    description_keywords = { "ORF2-like": "2", 
                            "ORF2": "2",
                            "precapsid":"2", 
                            "CP sequence": "2", 
                            "capsid": "2",
                            "ORF1a-like": "1A", 
                            "nsp1a-like": "1A", 
                            "ORF1A": "1A",
                            "1b-like": "1B", 
                            "RNA polymerase": "1B", 
                            "RdRp": "1B",
                            "ORF1b": "1B"
                            }
    
    # ENTRIES with known errors in annotation
    exceptions_ORF2 = ["MN725025", "KY047739", "S68561", "KP404151","KP404152"] # the last CDS in conflict ORF1b ORF2 is ORF2
    # PV999257 is actually ORF1a
    exceptions_1a = ["PV999257"]
    #AB518702 AB518703 is actually RdRp
    exceptions_1b = []
    
    # dictionary with ORF coordinates
    dict_coord = {}


    

    with open(input_file) as handle:
        records = list(SeqIO.parse(handle, 'gb'))

        # entries with no annotations
        no_annot = 0
        # entries with no annotations of target CDS
        no_annot_target = 0
        # CDS with no annotations of target ORFs
        notarget_annot_CDS = 0
        # CDS with no annotations
        no_annot_CDS = 0

        # Entries with CDS that has annotation "nonstructural protein"
        entries_onlynonstrprotein = []
        entries_onlynonstrprotein_short = []
        entries_conflicting_annotations = []
        entries_noannot = []
        entries_notarget_annot = []
        
        for rec in records:

            # Omit unverified sequences
            if "UNVERIFIED" in rec.description:
                continue
            # The coordinates of artificial sequences will not be extracted
            artificial_condition1 = ("patent" in rec.description.lower())
            artificial_condition2 = ("crispr" in rec.description.lower()) or ("oligonucleotide" in rec.description.lower())
            artificial_condition3 = "method" in rec.description.lower()
            artificial_condition4 = "modified microbial nucleic acid" in rec.description.lower()
            # Omit artificial sequences
            if artificial_condition1 or artificial_condition2 or artificial_condition3 or artificial_condition4:
                continue

            
            dict_coord[rec.name] = {}
            # iterate over record features

            # number of CDS
            cds_count = 0
            # number of annotated CDS with target ORFs
            cds_annot_count = 0

            # Set coordinates for nonstructural protein which type cannot be inferred from 
            NSP_start, NSP_end, NSP_strand = None, None, None
            for feature in rec.features:

                # check primers to identify the amplified region
                # !!! REVISE removing Mon269_Mon270
                if feature.type == 'source':
                    Mon340_Mon348 = False
                    Mon269_Mon270 = False
                    if feature.qualifiers.get("PCR_primers") != None:
                        #print(feature.qualifiers["PCR_primers"])
                        if "mon340" in feature.qualifiers["PCR_primers"][0].lower() or "mon348" in feature.qualifiers["PCR_primers"][0].lower():
                            Mon340_Mon348 = True
                            Mon269_Mon270 = False
                        elif "mon269" in feature.qualifiers["PCR_primers"][0].lower() or "mon270" in feature.qualifiers["PCR_primers"][0].lower():
                            Mon340_Mon348 = False
                            Mon269_Mon270 = True
        
                if feature.type == 'CDS':
                    cds_count += 1
                    
                    # Check codon start
                    if 'codon_start' in feature.qualifiers.keys():
                        cod_start = int(feature.qualifiers['codon_start'][0]) - 1
                        if cod_start<0:
                            print('Codon start < 0, something is wrong')
                    else:
                        cod_start = 0

                    # check all annotations in gene, product, note qualifiers
                    CDS_raw_annotations = []
                    for el in ('product', 'gene', 'note'):
                        CDS_raw_annotations.extend(feature.qualifiers.get(el, []))
                    
                    if len(CDS_raw_annotations) != 0:
                        # now we will leave annotations of target ORFs
                        CDS_annotations = list(map(lambda x: map_feature(x, orf_dict), CDS_raw_annotations))
                        CDS_annotations = list(filter(lambda x: x in orf_types, CDS_annotations))

                        # TARGET ORF ANNOTATIONS WERE  FOUND
                        if len(CDS_annotations) != 0:
                                                    
                            #print("Annotations were successfully found")
                            #print(CDS_annotations)

                            # check for consistency of CDS annotations
                            uniq_annotations = list(set(CDS_annotations))
                            if len(uniq_annotations) == 1:
                                CDS_product = uniq_annotations[0]
                                # CDS is a target ORF, the coordinates are not joined
                                if CDS_product in orf_types_final:
                                    dict_coord[rec.name][CDS_product] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                    dict_coord[rec.name][CDS_product + '-strand'] = feature.location.strand
                                    cds_annot_count +=1
                                elif CDS_product == "1AB":

                                    # check whether the coordinates are joined
                                    if len(feature.location.parts) == 2:
                                        dict_coord[rec.name]['1A'] = [int(feature.location.parts[0].start) + cod_start, int(feature.location.parts[0].end)]
                                        dict_coord[rec.name]['1A-strand'] = feature.location.parts[0].strand
                                        dict_coord[rec.name]['1B'] = [int(feature.location.parts[1].start), int(feature.location.parts[1].end)]
                                        dict_coord[rec.name]['1B-strand'] = feature.location.parts[1].strand
                                        cds_annot_count +=1
                                    elif len(feature.location.parts) == 1:
                                        dict_coord[rec.name]['1B'] = [int(feature.location.parts[0].start) + cod_start, int(feature.location.parts[0].end)]
                                        dict_coord[rec.name]['1B-strand'] = feature.location.parts[0].strand
                                        cds_annot_count +=1
                                    else:
                                        print("strange locations in {}".format(rec.name))
                                        print(feature.location)
                            else:
                                print("Conflicting CDS annotations for {}".format(rec.name))
                                #print(CDS_annotations)
                                #print(uniq_annotations)

                                present_1A = ('1A' in uniq_annotations)
                                present_1B = ('1B' in uniq_annotations)
                                present_1A_1B = present_1A and present_1B
                                present_1AB = ('1AB' in uniq_annotations)
                                present_1A_1AB = present_1A and present_1AB
                                present_1B_1AB = present_1B and present_1AB
                                present_2 = ('2' in uniq_annotations)
                                present_1AB_2 = (present_1A and present_2) or (present_1B and present_2) or (present_1AB and present_2) 
                                
                                
                                if present_1AB_2:
                                    if rec.name in exceptions_ORF2:
                                        dict_coord[rec.name]['2'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['2-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        print("Resolved for ORF2")
                                    else:
                                        print("Could not resolve the conflict")
                                        entries_conflicting_annotations.append(rec.name + ': ORF1ab + ORF2' + ':' + rec.description + '\n')
                                # If ORF1a and ORF1b are present, we choose ORF1b
                                elif present_1A_1B:
                                    if rec.name in exceptions_1a:
                                        dict_coord[rec.name]['1A'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['1A-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        print("Resolved for ORF1a")
                                    else:
                                        dict_coord[rec.name]['1B'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['1B-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        #entries_conflicting_annotations.append(rec.name + ': ORF1a + ORF1b' + ':' + rec.description + '\n')
                                        print("Resolved for ORF1b")
                                # ORF1ab with joined coordinates
                                elif len(feature.location.parts) == 2:
                                    dict_coord[rec.name]['1A'] = [int(feature.location.parts[0].start) + cod_start, int(feature.location.parts[0].end)]
                                    dict_coord[rec.name]['1A-strand'] = feature.location.parts[0].strand
                                    dict_coord[rec.name]['1B'] = [int(feature.location.parts[1].start), int(feature.location.parts[1].end)]
                                    dict_coord[rec.name]['1B-strand'] = feature.location.parts[1].strand
                                    cds_annot_count +=1
                                    print("Resolved for ORF1ab")
                                elif present_1A_1AB and ('1A' not in dict_coord[rec.name].keys()):
                                    dict_coord[rec.name]['1A'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                    dict_coord[rec.name]['1A-strand'] = feature.location.strand
                                    cds_annot_count +=1
                                    print("Resolved for ORF1a")
                                elif present_1B_1AB and ('1B' not in dict_coord[rec.name].keys()):
                                    dict_coord[rec.name]['1B'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                    dict_coord[rec.name]['1B-strand'] = feature.location.strand
                                    cds_annot_count +=1
                                    print("Resolved for ORF1b")
                                elif '1B' in dict_coord[rec.name].keys() or '1A' in dict_coord[rec.name].keys():
                                    print("The coordinates've been extracted from another CDS")
                            if rec.name == "MF973517":
                                print("MF973517")
                                print(cds_annot_count)
                                print(dict_coord[rec.name])
                        # NO TARGET ORF ANNOTATIONS WERE FOUND
                        else:            
                            #print("No annotations of target ORFs of CDS in {}".format(rec.name))
                            #print(CDS_raw_annotations)
                            #print(rec.description)
                            notarget_annot_CDS +=1

                            if "nonstructural protein" in CDS_raw_annotations:
                                #print("CDS of {} has the only annotation \'nonstructural protein\' ".format(rec.name))
                                if len(rec) > 300:
                                    if "orf1a" in rec.description.lower():
                                        dict_coord[rec.name]["1A"] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['1A-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        cds_count +=1
                                    # sequences covers ORF1b and ORF2
                                    elif  len(rec)< 700 and ("capsid" in rec.description.lower()):
                                        dict_coord[rec.name]["1B"] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['1B-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        cds_count +=1
                                    else:
                                        # ORF1b with joined coordinates
                                        #print(feature.location.parts)
                                        if len(feature.location.parts) == 2:
                                            dict_coord[rec.name]['1A'] = [int(feature.location.parts[0].start) + cod_start, int(feature.location.parts[0].end)]
                                            dict_coord[rec.name]['1A-strand'] = feature.location.parts[0].strand
                                            dict_coord[rec.name]['1B'] = [int(feature.location.parts[1].start), int(feature.location.parts[1].end)]
                                            dict_coord[rec.name]['1B-strand'] = feature.location.parts[1].strand
                                            cds_annot_count +=1
                                        else:
                                            NSP_start = int(feature.location.start) + cod_start
                                            NSP_end = int(feature.location.parts[0].end)
                                            NSP_strand = feature.location.strand
                                            #entries_onlynonstrprotein.append(rec.name + ':' + str(len(rec)) + ":"  +rec.description + '\n')
                                            # Тут записать координаты рамки и в конце проверить, нет ли других аннотаций

                                else:
                                    if Mon340_Mon348 == True:
                                        dict_coord[rec.name]["1A"] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                        dict_coord[rec.name]['1A-strand'] = feature.location.strand
                                        cds_annot_count +=1
                                        cds_count +=1
                                    else:
                                        '''
                                        These sequences cover ORF1a
                                        KX522573
                                        KX522572
                                        KX522571
                                        KX522570
                                        KX522569
                                        KX522568
                                        KX522567
                                        KX522566
                                        KP090043
                                        KP090042
                                        KP090041
                                        KP090040
                                        KP090039
                                        KP090038
                                        KP090037
                                        KP090036
                                        KP090035
                                        '''
                                        if "KX5225" in rec.name or "KP0900" in rec.name:
                                            dict_coord[rec.name]["1A"] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                            dict_coord[rec.name]['1A-strand'] = feature.location.strand
                                            cds_annot_count +=1
                                            cds_count +=1
                                        else:
                                            entries_onlynonstrprotein_short.append(rec.name + ':' + rec.description + '\n')
                    else:
                        #print("No annotations of CDS in {}".format(rec.name))
                        #print(rec.description)
                        #print(feature)
                        no_annot_CDS +=1

            # Determining the type of ORF indicated as "nonstructural protein"
            if NSP_start != None:
                present_1A = ('1A' in dict_coord[rec.name].keys())
                present_1B = ('1B' in dict_coord[rec.name].keys())
                present_2 = ('2' in dict_coord[rec.name].keys())
                present_1B2 = present_1B and present_2
                present_1A2 = present_1A and present_2

                if present_1B2:
                    dict_coord[rec.name]["1A"] = [NSP_start, NSP_end]
                    dict_coord[rec.name]['1A-strand'] = NSP_strand
                    cds_annot_count +=1
                    cds_count +=1
                elif present_1A2:
                    dict_coord[rec.name]["1B"] = [NSP_start, NSP_end]
                    dict_coord[rec.name]['1B-strand'] = NSP_strand
                    cds_annot_count +=1
                    cds_count +=1
                elif present_1A:
                    dict_coord[rec.name]["1B"] = [NSP_start, NSP_end]
                    dict_coord[rec.name]['1B-strand'] = NSP_strand
                    cds_annot_count +=1
                    cds_count +=1
                elif present_2:
                    dict_coord[rec.name]["1B"] = [NSP_start, NSP_end]
                    dict_coord[rec.name]['1B-strand'] = NSP_strand
                    cds_annot_count +=1
                    cds_count +=1
                elif present_1B:
                    dict_coord[rec.name]["1A"] = [NSP_start, NSP_end]
                    dict_coord[rec.name]['1A-strand'] = NSP_strand
                    cds_annot_count +=1
                    cds_count +=1
                else:
                    entries_onlynonstrprotein.append(rec.name + ':' + str(len(rec)) + ":"  +rec.description + '\n')

            
            '''
            # Check whether seq encodes ORF2
            if Mon269_Mon270 == True:
                print("Mon ORF2 primers: {}".format(rec.name))
                #dict_coord[rec.name]['2'] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                #dict_coord[rec.name]['2-strand'] = feature.location.strand
                #cds_annot_count +=1    
            '''


            if cds_annot_count == 0 or cds_count == 0:
                # Check the keywords in DEFINITION
                if len(rec) < 2700:
                    ORFs = map_keywords(rec.description,description_keywords)
                    if len(ORFs) == 1:
                        ORF_code = ORFs[0]
                        for feature in rec.features:
                            if feature.type == 'misc_feature':
                                dict_coord[rec.name][ORF_code] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                dict_coord[rec.name][ORF_code + '-strand'] = feature.location.strand
                                cds_annot_count +=1
                                cds_count +=1
                    elif len(ORFs) == 0:
                        print("No keywords were found in description for {}".format(rec.name))
                    else:
                        print("Conflicting keywords were found in description for {}".format(rec.name))
                        print(ORFs)
                else:
                    # Check misc features for annotations
                    for feature in rec.features:
                        if feature.type == "misc_feature":
                            miscfeature_raw_annotations = []
                            for el in ('product', 'gene', 'note'):
                                miscfeature_raw_annotations.extend(feature.qualifiers.get(el, []))
                            #print(miscfeature_raw_annotations)
                            
                            miscfeature_annotations = []
                            for f in miscfeature_raw_annotations:
                                ORFs = map_keywords(f,description_keywords)
                                miscfeature_annotations.extend(ORFs)
                            miscfeature_annotations = list(set(miscfeature_annotations))
                            if len(miscfeature_annotations) != 1:
                                print("Conflicting annotations in misc_feature for {}".format(rec.name))
                                print(miscfeature_raw_annotations)
                                print(miscfeature_annotations)
                            else:
                                ORF_code = miscfeature_annotations[0]
                                dict_coord[rec.name][ORF_code] = [int(feature.location.start) + cod_start, int(feature.location.end)]
                                dict_coord[rec.name][ORF_code + '-strand'] = feature.location.strand
                                cds_annot_count +=1
                                cds_count +=1

            if cds_annot_count == 0:
                no_annot_target +=1
                entries_notarget_annot.append(rec.name + ':' + str(len(rec)) + ':' + rec.description + '\n')
            if cds_count == 0:
                no_annot +=1
                entries_noannot.append(rec.name + ':' + str(len(rec)) + ':' + rec.description + '\n')
           



        # Write extracted coordinates to file
        with open(out_file_name, 'w') as out_file:
            line = "GBAC"
            for ORF in orf_types_final:
                line = line + ',' + ORF + ',' + ORF + '-strand'
            out_file.write(line + '\n')
            for rec_id, values in dict_coord.items():
                s = rec_id
                for orf in orf_types_final:
                    if orf in values:
                        s += f",{values[orf][0]}-{values[orf][1]},{values[orf+'-strand']}"
                    else:
                        s += ",NA-NA,NA"
                s += "\n"
                out_file.write(s)
        out_file.close()


        print("Entries with no CDS annotation: {}".format(no_annot))
        print("Entries with no CDS with target ORF annotation: {}".format(no_annot_target))
        print("CDS with no target ORFs: {}".format(notarget_annot_CDS))
        print("CDS with no annotations: {}".format(no_annot_CDS))

        with open(out_file_name_temp + '_noannotCDS.txt', 'w') as file:
            file.writelines(entries_noannot)

        with open(out_file_name_temp + '_noannot_targetCDS.txt', 'w') as file:
            file.writelines(entries_notarget_annot)
            
        with open(out_file_name_temp + '_noannot_targetCDS.txt', 'w') as file:
            file.writelines(entries_notarget_annot)

        with open(out_file_name_temp + '_conflictingannot.txt', 'w') as file:
            file.writelines(entries_conflicting_annotations)

        with open(out_file_name_temp + '_onlyNSP_long.txt', 'w') as file:
            file.writelines(entries_onlynonstrprotein)
            
        with open(out_file_name_temp + '_onlyNSP_short.txt', 'w') as file:
            file.writelines(entries_onlynonstrprotein_short)

        
        return 0

# %%
file_gb = fetch_seq_from_Nucleotide('"txid39733"[Organism]' , "data/Astroviridae_15102025.gb")
# Out:
# Query to GenBank Nucleotide database:""txid39733"[Organism]"
# Number of records found: 16012
# 16012 records will be downloaded
# Downloaded 500 sequences
# Downloaded 1000 sequences
# Downloaded 1500 sequences
# Downloaded 2000 sequences
# Downloaded 2500 sequences
# Downloaded 3000 sequences
# Downloaded 3500 sequences
# Downloaded 4000 sequences
# Downloaded 4500 sequences
# Downloaded 5000 sequences
# Downloaded 5500 sequences
# Downloaded 6000 sequences
# Downloaded 6500 sequences
# Downloaded 7000 sequences
# Downloaded 7500 sequences
# Downloaded 8000 sequences
# Downloaded 8500 sequences
# Downloaded 9000 sequences
# Downloaded 9500 sequences
# Downloaded 10000 sequences
# Downloaded 10500 sequences
# Downloaded 11000 sequences
# Downloaded 11500 sequences
# Downloaded 12000 sequences
# Downloaded 12500 sequences
# Downloaded 13000 sequences
# Downloaded 13500 sequences
# Downloaded 14000 sequences
# Downloaded 14500 sequences
# Downloaded 15000 sequences
# Downloaded 15500 sequences
# Downloaded 16000 sequences
# Finished

# %%
input_file = "data/Astroviridae_15102025.gb"
data = fetch_metadata_from_gb(input_file)

# %%
data[data["Artificial"] == "Yes"]
# Out:
#              Version                                      GenBank title  \
# PG036827  PG036827.1  JP 2022536474-A/8: Methods and Compositions of...
# PG036826  PG036826.1  JP 2022536474-A/7: Methods and Compositions of...
# PG036825  PG036825.1  JP 2022536474-A/6: Methods and Compositions of...
# PG036824  PG036824.1  JP 2022536474-A/5: Methods and Compositions of...
# PG036823  PG036823.1  JP 2022536474-A/4: Methods and Compositions of...
# ...              ...                                                ...
# GN354831  GN354831.1             Sequence 4595 from Patent WO2007130519
# GN354830  GN354830.1             Sequence 4594 from Patent WO2007130519
# GN354829  GN354829.1             Sequence 4593 from Patent WO2007130519
# DL470173  DL470173.1  ANTISENSE ANTIVIRAL COMPOUND AND METHOD FOR TR...
# AX348182  AX348182.1                  Sequence 52 from Patent WO0202811
#
#          Release date       Organism name  \
# PG036827  28-FEB-2025    Human astrovirus
# PG036826  28-FEB-2025    Human astrovirus
# PG036825  28-FEB-2025    Human astrovirus
# PG036824  28-FEB-2025    Human astrovirus
# PG036823  28-FEB-2025    Human astrovirus
# ...               ...                 ...
# GN354831  12-MAY-2009    Mamastrovirus 13
# GN354830  12-MAY-2009    Mamastrovirus 13
# GN354829  12-MAY-2009    Mamastrovirus 13
# DL470173  22-DEC-2008    Human astrovirus
# AX348182  06-FEB-2002  Human astrovirus 1
#
#                                               Virus Lineage  \
# PG036827  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# PG036826  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# PG036825  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# PG036824  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# PG036823  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# ...                                                     ...
# GN354831  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# GN354830  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# GN354829  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# DL470173  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
# AX348182  Viruses;Riboviria;Orthornavirae;Pisuviricota;S...
#
#                         Species        Family  Length Submitters Strain  \
# PG036827                     NA  Astroviridae    5388        NaN     NA
# PG036826                     NA  Astroviridae    5412        NaN     NA
# PG036825                     NA  Astroviridae    5358        NaN     NA
# PG036824                     NA  Astroviridae    5358        NaN     NA
# PG036823                     NA  Astroviridae    5337        NaN     NA
# ...                         ...           ...     ...        ...    ...
# GN354831     Mamastrovirus ovis  Astroviridae      60        NaN     NA
# GN354830     Mamastrovirus ovis  Astroviridae      60        NaN     NA
# GN354829     Mamastrovirus ovis  Astroviridae      60        NaN     NA
# DL470173                     NA  Astroviridae      40        NaN     NA
# AX348182  Mamastrovirus hominis  Astroviridae      67        NaN     NA
#
#          Isolate Geo location Country Collection date Tissue/Specimen/Source  \
# PG036827      NA           NA      NA              NA                     NA
# PG036826      NA           NA      NA              NA                     NA
# PG036825      NA           NA      NA              NA                     NA
# PG036824      NA           NA      NA              NA                     NA
# PG036823      NA           NA      NA              NA                     NA
# ...          ...          ...     ...             ...                    ...
# GN354831      NA           NA      NA              NA                     NA
# GN354830      NA           NA      NA              NA                     NA
# GN354829      NA           NA      NA              NA                     NA
# DL470173      NA           NA      NA              NA                     NA
# AX348182      NA           NA      NA              NA                     NA
#
#          Host Environmental  CDS count Artificial UNVERIFIED
# PG036827   NA            No          0        Yes         No
# PG036826   NA            No          0        Yes         No
# PG036825   NA            No          0        Yes         No
# PG036824   NA            No          0        Yes         No
# PG036823   NA            No          0        Yes         No
# ...       ...           ...        ...        ...        ...
# GN354831   NA            No          0        Yes         No
# GN354830   NA            No          0        Yes         No
# GN354829   NA            No          0        Yes         No
# DL470173   NA            No          0        Yes         No
# AX348182   NA            No          0        Yes         No
#
# [102 rows x 20 columns]

# %%
orf_coord("data/Astroviridae_15102025.gb", "ORF_names.csv")
# Out:
# D:\Virology\RNA_viruses\Astrovirus\Astroviridae_database\Astroviridae_15102025_orf-coords.csv
# No keywords were found in description for PX395426
# No keywords were found in description for PX395425
# No keywords were found in description for PX395424
# No keywords were found in description for PX395423
# No keywords were found in description for PX395422
# No keywords were found in description for OR951076
# No keywords were found in description for OR951065
# No keywords were found in description for OR951063
# No keywords were found in description for OR951056
# No keywords were found in description for OR951044
# No keywords were found in description for OR951043
# No keywords were found in description for OR951029
# No keywords were found in description for OR951024
# No keywords were found in description for OR951013
# No keywords were found in description for PX095754
# No keywords were found in description for PX113254
# Conflicting CDS annotations for PV999257
# Resolved for ORF1b
# Conflicting annotations in misc_feature for PV793828
# ['similar to non-structural polyprotein']
# []
# No keywords were found in description for PQ421851
# No keywords were found in description for PP211271
# No keywords were found in description for PP211222
# No keywords were found in description for PP211221
# Conflicting CDS annotations for PV524668
# Resolved for ORF1ab
# Conflicting CDS annotations for PV524668
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for PV400867
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for PV400866
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for PV400865
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for FJ571068
# Resolved for ORF1b
# Conflicting CDS annotations for FJ571067
# Resolved for ORF1b
# Conflicting CDS annotations for FJ571066
# Resolved for ORF1b
# Conflicting CDS annotations for FJ571065
# Resolved for ORF1b
# Conflicting CDS annotations for PV189393
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189392
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189391
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189390
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189389
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189388
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189387
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189386
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189385
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189384
# Resolved for ORF1ab
# Conflicting CDS annotations for PV189383
# Resolved for ORF1ab
# Conflicting CDS annotations for PQ541178
# Resolved for ORF1ab
# No keywords were found in description for PL092225
# No keywords were found in description for PL092217
# No keywords were found in description for PL092213
# Conflicting CDS annotations for PQ525428
# Resolved for ORF1a
# Conflicting CDS annotations for PQ525428
# Resolved for ORF1b
# Conflicting CDS annotations for PQ055539
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055538
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055537
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055536
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055535
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055533
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055532
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055530
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055529
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055528
# Could not resolve the conflict
# Conflicting CDS annotations for PQ055524
# Could not resolve the conflict
# No keywords were found in description for PQ110289
# Conflicting CDS annotations for PP968017
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for OQ758048
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758047
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758046
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758045
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758044
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758043
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758042
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758041
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758040
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758039
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758038
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758037
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758036
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758035
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758034
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758033
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758032
# Resolved for ORF1b
# Conflicting CDS annotations for OQ758031
# Resolved for ORF1b
# Conflicting annotations in misc_feature for OR871062
# ['similar to hypothetical protein']
# []
# Conflicting annotations in misc_feature for OR871061
# ['similar to hypothetical protein']
# []
# No keywords were found in description for OR871060
# No keywords were found in description for OR800315
# No keywords were found in description for OQ986647
# No keywords were found in description for OR645486
# Conflicting CDS annotations for OR626615
# Resolved for ORF1a
# No keywords were found in description for OQ802763
# No keywords were found in description for OQ802762
# No keywords were found in description for OQ802757
# No keywords were found in description for OQ802714
# No keywords were found in description for OR234613
# No keywords were found in description for OR234607
# No keywords were found in description for OQ709194
# No keywords were found in description for OQ709192
# No keywords were found in description for OQ709190
# No keywords were found in description for OQ709188
# Conflicting CDS annotations for ON400505
# Resolved for ORF1a
# Conflicting CDS annotations for ON382522
# Resolved for ORF1a
# Conflicting CDS annotations for ON382521
# Resolved for ORF1a
# Conflicting CDS annotations for ON382520
# Resolved for ORF1a
# Conflicting CDS annotations for ON382519
# Resolved for ORF1a
# Conflicting annotations in misc_feature for OQ599876
# ['similar to ORF3']
# []
# No keywords were found in description for ON932807
# Conflicting CDS annotations for OM469237
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469236
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469235
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469234
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469233
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469232
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469231
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469230
# Resolved for ORF1ab
# Conflicting CDS annotations for OM469229
# Resolved for ORF1ab
# Conflicting CDS annotations for OP413943
# Could not resolve the conflict
# Conflicting CDS annotations for ON715001
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for ON714997
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for ON714996
# The coordinates've been extracted from another CDS
# No keywords were found in description for OP474168
# Conflicting CDS annotations for ON714999
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for ON714998
# The coordinates've been extracted from another CDS
# No keywords were found in description for OK483336
# No keywords were found in description for OK483335
# Conflicting CDS annotations for OP020144
# Resolved for ORF1a
# Conflicting CDS annotations for MW787033
# Resolved for ORF1b
# Conflicting CDS annotations for MW787031
# Resolved for ORF1b
# Conflicting CDS annotations for MW787030
# Resolved for ORF1b
# Conflicting CDS annotations for MW787029
# Resolved for ORF1b
# Conflicting CDS annotations for MW787028
# Resolved for ORF1b
# Conflicting CDS annotations for MW787027
# Resolved for ORF1b
# Conflicting CDS annotations for MW787026
# Resolved for ORF1b
# Conflicting CDS annotations for MW787025
# Resolved for ORF1b
# Conflicting CDS annotations for MW787024
# Resolved for ORF1b
# Conflicting CDS annotations for MW787023
# Resolved for ORF1b
# Conflicting CDS annotations for MW787022
# Resolved for ORF1b
# Conflicting CDS annotations for MW787021
# Resolved for ORF1b
# Conflicting CDS annotations for MW787020
# Resolved for ORF1b
# Conflicting CDS annotations for MW787019
# Resolved for ORF1b
# Conflicting CDS annotations for MW787017
# Resolved for ORF1b
# Conflicting CDS annotations for MW787016
# Resolved for ORF1b
# Conflicting CDS annotations for MW787015
# Resolved for ORF1b
# Conflicting CDS annotations for MW787014
# Resolved for ORF1b
# Conflicting CDS annotations for MW787013
# Resolved for ORF1b
# No keywords were found in description for ON304004
# No keywords were found in description for OM953853
# Conflicting CDS annotations for MT333760
# Resolved for ORF1a
# Conflicting CDS annotations for MT333759
# Resolved for ORF1a
# Conflicting CDS annotations for MT333758
# Resolved for ORF1a
# Conflicting CDS annotations for MT333757
# Resolved for ORF1a
# Conflicting CDS annotations for MT333756
# Resolved for ORF1a
# Conflicting CDS annotations for MT333755
# Resolved for ORF1a
# Conflicting CDS annotations for MT333754
# Resolved for ORF1a
# Conflicting CDS annotations for MT333753
# Resolved for ORF1a
# Conflicting CDS annotations for MT333752
# Resolved for ORF1a
# Conflicting CDS annotations for MT333751
# Resolved for ORF1a
# Conflicting CDS annotations for MT333750
# Resolved for ORF1a
# Conflicting CDS annotations for MT333749
# Resolved for ORF1a
# Conflicting CDS annotations for MT333748
# Resolved for ORF1a
# Conflicting CDS annotations for MT333747
# Resolved for ORF1a
# Conflicting CDS annotations for MT333746
# Resolved for ORF1a
# Conflicting CDS annotations for MT333745
# Resolved for ORF1a
# Conflicting CDS annotations for MZ150559
# Resolved for ORF1ab
# No keywords were found in description for OL739530
# No keywords were found in description for MW239504
# No keywords were found in description for MW239381
# No keywords were found in description for MW239289
# No keywords were found in description for MW239205
# No keywords were found in description for MW239195
# No keywords were found in description for MW239194
# Conflicting CDS annotations for MZ576222
# Resolved for ORF1a
# No keywords were found in description for MZ291967
# No keywords were found in description for MW924358
# No keywords were found in description for MW924357
# No keywords were found in description for MW924356
# Conflicting CDS annotations for MW684833
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684832
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684829
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684827
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684826
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684825
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684824
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684822
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684821
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684820
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684819
# Resolved for ORF1ab
# Conflicting CDS annotations for MW684818
# Resolved for ORF1ab
# Conflicting CDS annotations for MT740274
# Resolved for ORF1b
# No keywords were found in description for MW645022
# No keywords were found in description for MW645021
# Conflicting CDS annotations for MW249010
# Resolved for ORF1b
# Conflicting CDS annotations for MW592379
# Resolved for ORF1a
# Conflicting CDS annotations for MW592378
# Resolved for ORF1a
# Conflicting CDS annotations for MW592377
# Resolved for ORF1a
# Conflicting CDS annotations for MT492440
# Resolved for ORF1b
# Conflicting CDS annotations for MT492439
# Resolved for ORF1b
# Conflicting CDS annotations for MT492438
# Resolved for ORF1b
# Conflicting CDS annotations for MT492437
# Resolved for ORF1b
# Conflicting CDS annotations for MT492436
# Resolved for ORF1b
# Conflicting CDS annotations for MT492435
# Resolved for ORF1b
# Conflicting CDS annotations for MT492434
# Resolved for ORF1b
# Conflicting CDS annotations for MT492433
# Resolved for ORF1b
# Conflicting CDS annotations for MT492432
# Resolved for ORF1b
# Conflicting CDS annotations for MT492431
# Resolved for ORF1b
# Conflicting CDS annotations for MT492430
# Resolved for ORF1b
# Conflicting CDS annotations for MT492429
# Resolved for ORF1b
# Conflicting CDS annotations for MT492428
# Resolved for ORF1b
# Conflicting CDS annotations for MT492427
# Resolved for ORF1b
# Conflicting CDS annotations for MT492426
# Resolved for ORF1b
# Conflicting CDS annotations for MT492425
# Resolved for ORF1b
# Conflicting CDS annotations for MT492424
# Resolved for ORF1b
# Conflicting CDS annotations for MT492423
# Resolved for ORF1b
# Conflicting CDS annotations for MT492422
# Resolved for ORF1b
# No keywords were found in description for MT896156
# No keywords were found in description for MT896155
# Conflicting CDS annotations for MT506231
# Resolved for ORF1ab
# Conflicting CDS annotations for MT506231
# Resolved for ORF1b
# Conflicting CDS annotations for MH123921
# Resolved for ORF1b
# Conflicting CDS annotations for MH123920
# Resolved for ORF1b
# Conflicting CDS annotations for MH123919
# Resolved for ORF1b
# Conflicting CDS annotations for MH123918
# Resolved for ORF1b
# Conflicting CDS annotations for MH123917
# Resolved for ORF1b
# Conflicting CDS annotations for MH123916
# Resolved for ORF1b
# Conflicting CDS annotations for MH123915
# Resolved for ORF1b
# Conflicting CDS annotations for MH123914
# Resolved for ORF1b
# Conflicting CDS annotations for MH123913
# Resolved for ORF1b
# Conflicting CDS annotations for MH123912
# Resolved for ORF1b
# Conflicting CDS annotations for MH123911
# Resolved for ORF1b
# Conflicting CDS annotations for MH123910
# Resolved for ORF1b
# Conflicting CDS annotations for MH123909
# Resolved for ORF1b
# Conflicting CDS annotations for MH123908
# Resolved for ORF1b
# Conflicting CDS annotations for MH123907
# Resolved for ORF1b
# Conflicting CDS annotations for MH123906
# Resolved for ORF1b
# Conflicting CDS annotations for MH123905
# Resolved for ORF1b
# Conflicting CDS annotations for MH123904
# Resolved for ORF1b
# Conflicting CDS annotations for MH123903
# Resolved for ORF1b
# Conflicting CDS annotations for MH123902
# Resolved for ORF1b
# Conflicting CDS annotations for MH123901
# Resolved for ORF1b
# Conflicting CDS annotations for MH123900
# Resolved for ORF1b
# Conflicting CDS annotations for MH123899
# Resolved for ORF1b
# Conflicting CDS annotations for MH123898
# Resolved for ORF1b
# Conflicting CDS annotations for MH123897
# Resolved for ORF1b
# Conflicting CDS annotations for MH123896
# Resolved for ORF1b
# Conflicting CDS annotations for MH123895
# Resolved for ORF1b
# Conflicting CDS annotations for MN725025
# Resolved for ORF2
# No keywords were found in description for MN733910
# No keywords were found in description for MN036159
# No keywords were found in description for MN036131
# No keywords were found in description for MN035893
# No keywords were found in description for MN035574
# No keywords were found in description for MN035429
# No keywords were found in description for MN035369
# No keywords were found in description for MN034849
# No keywords were found in description for MN034422
# No keywords were found in description for MN034197
# No keywords were found in description for MN033907
# No keywords were found in description for MN033591
# No keywords were found in description for MN033141
# Conflicting CDS annotations for NC_043103
# Resolved for ORF1b
# Conflicting CDS annotations for NC_043100
# Resolved for ORF1b
# Conflicting CDS annotations for NC_043098
# Resolved for ORF1b
# No keywords were found in description for MK387179
# No keywords were found in description for MK387178
# No keywords were found in description for MK387177
# Conflicting CDS annotations for HM484374
# Resolved for ORF1ab
# No keywords were found in description for MG846413
# Conflicting CDS annotations for NC_013443
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for MG004212
# Resolved for ORF1b
# Conflicting CDS annotations for MG004211
# Resolved for ORF1b
# Conflicting CDS annotations for MG004210
# Resolved for ORF1b
# Conflicting CDS annotations for MG004209
# Resolved for ORF1b
# Conflicting CDS annotations for MG004208
# Resolved for ORF1b
# Conflicting CDS annotations for MG004207
# Resolved for ORF1b
# Conflicting CDS annotations for MG004206
# Resolved for ORF1b
# Conflicting CDS annotations for MG004205
# Resolved for ORF1b
# Conflicting CDS annotations for MG004204
# Resolved for ORF1b
# Conflicting CDS annotations for MG004203
# Resolved for ORF1b
# Conflicting CDS annotations for MG004202
# Resolved for ORF1b
# Conflicting CDS annotations for MG004201
# Resolved for ORF1b
# Conflicting CDS annotations for MG004200
# Resolved for ORF1b
# Conflicting CDS annotations for MG004199
# Resolved for ORF1b
# Conflicting CDS annotations for MG004198
# Resolved for ORF1b
# Conflicting CDS annotations for MG004197
# Resolved for ORF1b
# Conflicting CDS annotations for MG004196
# Resolved for ORF1b
# Conflicting CDS annotations for MG004195
# Resolved for ORF1b
# No keywords were found in description for KC411816
# MF973517
# 1
# {'1A': [0, 502], '1A-strand': 1}
# Conflicting CDS annotations for GQ415660
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for KX033447
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for KY047739
# Resolved for ORF2
# Conflicting CDS annotations for KX060809
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for KX060808
# The coordinates've been extracted from another CDS
# Conflicting CDS annotations for KT963070
# Resolved for ORF1b
# Conflicting CDS annotations for KT963069
# Resolved for ORF1b
# Conflicting CDS annotations for KT757532
# Resolved for ORF1b
# Conflicting CDS annotations for KT757531
# Resolved for ORF1b
# Conflicting CDS annotations for KT757530
# Resolved for ORF1b
# Conflicting CDS annotations for KT757529
# Resolved for ORF1b
# No keywords were found in description for DQ327618
# No keywords were found in description for DQ327617
# No keywords were found in description for DQ327616
# No keywords were found in description for DQ327615
# No keywords were found in description for DQ327614
# No keywords were found in description for DQ327613
# No keywords were found in description for DQ327612
# No keywords were found in description for DQ327611
# No keywords were found in description for DQ327610
# No keywords were found in description for DQ327609
# No keywords were found in description for DQ327608
# No keywords were found in description for AY831433
# Conflicting CDS annotations for S68561
# Resolved for ORF2
# Conflicting CDS annotations for HM120878
# Resolved for ORF1b
# Conflicting CDS annotations for HM120877
# Resolved for ORF1b
# Conflicting CDS annotations for HM120876
# Resolved for ORF1b
# Conflicting CDS annotations for AF290509
# Resolved for ORF1a
# Conflicting CDS annotations for AF290508
# Resolved for ORF1a
# Conflicting CDS annotations for AF290507
# Resolved for ORF1a
# Conflicting CDS annotations for AF290506
# Resolved for ORF1a
# Conflicting CDS annotations for AF290505
# Resolved for ORF1a
# Conflicting CDS annotations for AF290504
# Resolved for ORF1a
# No keywords were found in description for AY027809
# Conflicting CDS annotations for LN879482
# Resolved for ORF1ab
# Conflicting CDS annotations for KJ496050
# Resolved for ORF1b
# Conflicting CDS annotations for KJ496049
# Resolved for ORF1b
# Conflicting CDS annotations for KJ496048
# Resolved for ORF1b
# Conflicting CDS annotations for KJ496047
# Resolved for ORF1b
# Conflicting CDS annotations for KJ496046
# Resolved for ORF1b
# Conflicting CDS annotations for KJ496045
# Resolved for ORF1b
# Conflicting CDS annotations for KP264970
# The coordinates've been extracted from another CDS
# No keywords were found in description for S47249
# Conflicting CDS annotations for KP404152
# Resolved for ORF2
# Conflicting CDS annotations for KP404151
# Resolved for ORF2
# Conflicting CDS annotations for KJ571485
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571484
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571483
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571482
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571481
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571480
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571479
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571478
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571477
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571476
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571475
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571474
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571473
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571472
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571471
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571470
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571469
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571468
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571467
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571466
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571465
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571464
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571463
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571462
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571461
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571460
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571459
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571458
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571457
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571456
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571455
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571454
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571453
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571452
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571451
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571450
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571449
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571448
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571447
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571446
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571445
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571444
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571443
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571442
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571441
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571440
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571439
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571438
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571437
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571436
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571435
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571434
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571433
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571432
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571431
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571430
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571429
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571428
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571427
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571426
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571425
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571424
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571423
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571422
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571421
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571420
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571419
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571418
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571417
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571416
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571415
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571414
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571413
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571412
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571411
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571410
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571409
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571408
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571407
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571406
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571405
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571404
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571403
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571402
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571401
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571400
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571399
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571398
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571397
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571396
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571395
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571394
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571393
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571392
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571391
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571390
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571389
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571388
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571387
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571386
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571385
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571384
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571383
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571382
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571381
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571380
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571379
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571378
# Resolved for ORF1b
# Conflicting CDS annotations for KJ571377
# Resolved for ORF1b
# No keywords were found in description for KC599256
# Conflicting CDS annotations for KJ633799
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633798
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633797
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633796
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633795
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633794
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633793
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633792
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633791
# Resolved for ORF1b
# Conflicting CDS annotations for KJ633790
# Resolved for ORF1b
# Conflicting CDS annotations for KJ596489
# Resolved for ORF1b
# Conflicting CDS annotations for JX087965
# Resolved for ORF1b
# Conflicting CDS annotations for JF327667
# Resolved for ORF1b
# Conflicting CDS annotations for AB518703
# Resolved for ORF1b
# Conflicting CDS annotations for AB518702
# Resolved for ORF1b
# Conflicting CDS annotations for AB243067
# Resolved for ORF1b
# Conflicting CDS annotations for JX087964
# Resolved for ORF1b
# Conflicting CDS annotations for JX087963
# Resolved for ORF1b
# No keywords were found in description for HUAIMMREAB
# No keywords were found in description for HUAIMMREAA
# No keywords were found in description for HUA3TERMS
# No keywords were found in description for EF490429
# No keywords were found in description for GU222334
# No keywords were found in description for GU222333
# No keywords were found in description for GU222332
# No keywords were found in description for GU222331
# No keywords were found in description for GU222330
# No keywords were found in description for GU222348
# No keywords were found in description for GU222347
# No keywords were found in description for GU222346
# No keywords were found in description for GU222345
# No keywords were found in description for GU222344
# No keywords were found in description for GU222343
# No keywords were found in description for GU222342
# No keywords were found in description for GU222341
# No keywords were found in description for GU222340
# No keywords were found in description for GU222339
# No keywords were found in description for GU222338
# No keywords were found in description for GU222337
# No keywords were found in description for GU222336
# No keywords were found in description for GU222335
# No keywords were found in description for ATVPOLY4A
# No keywords were found in description for ATVPOLY1A
# No keywords were found in description for Z16420
# Conflicting CDS annotations for AB126674
# Resolved for ORF1a
# Conflicting CDS annotations for AB126673
# Resolved for ORF1a
# Conflicting CDS annotations for AB126672
# Resolved for ORF1a
# Conflicting CDS annotations for AB126671
# Resolved for ORF1a
# Conflicting CDS annotations for AB126670
# Resolved for ORF1a
# Conflicting CDS annotations for AB116554
# Resolved for ORF1a
# No keywords were found in description for Z11682
# Entries with no CDS annotation: 64
# Entries with no CDS with target ORF annotation: 179
# CDS with no target ORFs: 706
# CDS with no annotations: 2
# 0

# %% [markdown]
# Два раза встречается ORF1ab polyprotein в PX095750

# %%
def split_genome_and_reverse(input_file, coord_file):
    '''
    Splits nucleotide sequences from input_file into ORFs using their coordinates from 
    coord_file

    Input:
        input_file - file with nucleotide sequences in fasta-format
        coord_file - text file with coordinates of NTRs

    '''
    

    coord_df = pd.read_csv(coord_file, sep=",", index_col=0)
    #orfs = list(coord_df.columns)
    orfs = ['1A', '1B', '2']
    print(coord_df)
    dict_orfs = {}
    for orf in orfs:
        dict_orfs[orf] = list()
    seqs = SeqIO.parse(open(input_file), format='fasta')
    for seq in seqs:
        # accession number of sequence
        acc = seq.id.split("_")[0]
        if acc == 'NC' or acc == 'AC':
            acc = '_'.join([acc,seq.id.split("_")[1]])
        for orf in orfs:            
            if (acc in coord_df.index) and (coord_df.loc[acc,orf] != 'NA-NA'):
                cd = coord_df[orf][acc]
                s, e = [int(x) for x in cd.split('-')]
                seq_orf = copy.deepcopy(seq)
                seq_orf.seq = seq.seq[s:e]
                strand_col = f"{orf}-strand"
                if strand_col in coord_df.columns:
                    strand_value = coord_df.loc[acc, strand_col]
                    if strand_value == -1:
                        seq_orf.seq = seq_orf.seq.reverse_complement()
                        seq_orf.id += "_reverse"
                        seq_orf.description = seq_orf.id
                        print(acc)
                dict_orfs[orf].append(seq_orf)
            else:
                print('{} not in coord file'.format(acc))
    out_temp = os.path.splitext(input_file)[0]
    for orf in dict_orfs.keys():
        outfile = out_temp + '_' + orf + '.fasta'
        SeqIO.write(dict_orfs[orf], outfile, "fasta")

# %%
input_file = "data/Astroviridae_15102025.fasta"
coord_file = "data/Astroviridae_15102025_orf-coords.csv"

# %%
split_genome_and_reverse(input_file,coord_file)
# Out:
#                1A  1A-strand         1B  1B-strand          2  2-strand
# GBAC
# PV418556   0-2670        1.0  2621-4157        1.0  3957-6444       1.0
# PV418555   0-2667        1.0  2618-4154        1.0  3954-6466       1.0
# PV418548    NA-NA        NaN      NA-NA        NaN   116-2447       1.0
# PV418547    NA-NA        NaN      NA-NA        NaN    57-2416       1.0
# PV418557  59-2606        1.0  2569-4138        1.0  4091-6455       1.0
# ...           ...        ...        ...        ...        ...       ...
# Y08628      NA-NA        NaN      NA-NA        NaN      1-220       1.0
# Y08627      NA-NA        NaN      NA-NA        NaN      1-220       1.0
# Z66541      NA-NA        NaN      NA-NA        NaN     0-2349       1.0
# Z46658      NA-NA        NaN      NA-NA        NaN     0-2337       1.0
# HUANSSPS    NA-NA        NaN      NA-NA        NaN      NA-NA       NaN
#
# [15516 rows x 6 columns]
# PV418548 not in coord file
# PV418548 not in coord file
# PV418547 not in coord file
# PV418547 not in coord file
# PV418552 not in coord file
# PV418552 not in coord file
# PV418551 not in coord file
# PV418551 not in coord file
# PV418550 not in coord file
# PV418550 not in coord file
# PV418549 not in coord file
# PV418549 not in coord file
# PV418546 not in coord file
# PV418545 not in coord file
# PX395423 not in coord file
# PX395423 not in coord file
# PX395423 not in coord file
# PX395422 not in coord file
# PX395422 not in coord file
# PX395422 not in coord file
# PX378139 not in coord file
# PX378138 not in coord file
# PX378137 not in coord file
# PX378136 not in coord file
# PX378135 not in coord file
# PX378134 not in coord file
# PX378133 not in coord file
# PX378132 not in coord file
# PX378131 not in coord file
# PV211181 not in coord file
# PV211181 not in coord file
# PV211180 not in coord file
# PV211180 not in coord file
# PV211179 not in coord file
# PV211179 not in coord file
# PV211178 not in coord file
# PV211178 not in coord file
# PV211177 not in coord file
# PV211177 not in coord file
# PV211176 not in coord file
# PV211176 not in coord file
# PX289198 not in coord file
# PX289198 not in coord file
# PX289198 not in coord file
# PX289197 not in coord file
# PX289197 not in coord file
# PX289197 not in coord file
# PX289196 not in coord file
# PX289196 not in coord file
# PX289196 not in coord file
# OR951096 not in coord file
# OR951096 not in coord file
# OR951095 not in coord file
# OR951095 not in coord file
# OR951094 not in coord file
# OR951094 not in coord file
# OR951093 not in coord file
# OR951093 not in coord file
# OR951092 not in coord file
# OR951092 not in coord file
# OR951091 not in coord file
# OR951091 not in coord file
# OR951090 not in coord file
# OR951090 not in coord file
# OR951089 not in coord file
# OR951089 not in coord file
# OR951088 not in coord file
# OR951085 not in coord file
# OR951085 not in coord file
# OR951084 not in coord file
# OR951084 not in coord file
# OR951083 not in coord file
# OR951083 not in coord file
# OR951081 not in coord file
# OR951078 not in coord file
# OR951078 not in coord file
# OR951077 not in coord file
# OR951077 not in coord file
# OR951076 not in coord file
# OR951076 not in coord file
# OR951076 not in coord file
# OR951075 not in coord file
# OR951073 not in coord file
# OR951073 not in coord file
# OR951072 not in coord file
# OR951071 not in coord file
# OR951071 not in coord file
# OR951070 not in coord file
# OR951070 not in coord file
# OR951069 not in coord file
# OR951069 not in coord file
# OR951067 not in coord file
# OR951067 not in coord file
# OR951066 not in coord file
# OR951066 not in coord file
# OR951065 not in coord file
# OR951065 not in coord file
# OR951065 not in coord file
# OR951064 not in coord file
# OR951064 not in coord file
# OR951063 not in coord file
# OR951063 not in coord file
# OR951063 not in coord file
# OR951062 not in coord file
# OR951062 not in coord file
# OR951061 not in coord file
# OR951061 not in coord file
# OR951060 not in coord file
# OR951059 not in coord file
# OR951058 not in coord file
# OR951057 not in coord file
# OR951057 not in coord file
# OR951056 not in coord file
# OR951056 not in coord file
# OR951056 not in coord file
# OR951054 not in coord file
# OR951054 not in coord file
# OR951052 not in coord file
# OR951051 not in coord file
# OR951051 not in coord file
# OR951050 not in coord file
# OR951050 not in coord file
# OR951046 not in coord file
# OR951046 not in coord file
# OR951044 not in coord file
# OR951044 not in coord file
# OR951044 not in coord file
# OR951043 not in coord file
# OR951043 not in coord file
# OR951043 not in coord file
# OR951042 not in coord file
# OR951041 not in coord file
# OR951039 not in coord file
# OR951039 not in coord file
# OR951038 not in coord file
# OR951037 not in coord file
# OR951037 not in coord file
# OR951035 not in coord file
# OR951033 not in coord file
# OR951031 not in coord file
# OR951031 not in coord file
# OR951029 not in coord file
# OR951029 not in coord file
# OR951029 not in coord file
# OR951028 not in coord file
# OR951024 not in coord file
# OR951024 not in coord file
# OR951024 not in coord file
# OR951020 not in coord file
# OR951020 not in coord file
# OR951019 not in coord file
# OR951019 not in coord file
# OR951018 not in coord file
# OR951017 not in coord file
# OR951015 not in coord file
# OR951015 not in coord file
# OR951014 not in coord file
# OR951013 not in coord file
# OR951013 not in coord file
# OR951013 not in coord file
# OR951012 not in coord file
# OR951012 not in coord file
# OR951011 not in coord file
# OR951011 not in coord file
# OR951010 not in coord file
# OR951009 not in coord file
# OR951009 not in coord file
# OR951008 not in coord file
# OR951008 not in coord file
# OR951007 not in coord file
# OR951007 not in coord file
# PX280286 not in coord file
# PX280286 not in coord file
# PX237220 not in coord file
# PX237220 not in coord file
# PX237221 not in coord file
# PX237221 not in coord file
# PX132666 not in coord file
# PX132665 not in coord file
# PX132664 not in coord file
# PP239060 not in coord file
# PX146716 not in coord file
# PX146716 not in coord file
# PX095946
# PX095946
# PX095946
# PX095874 not in coord file
# PX095874
# PX095874
# PX095873 not in coord file
# PX095873
# PX095873 not in coord file
# PX095817 not in coord file
# PX095817 not in coord file
# PX095817
# PX095816 not in coord file
# PX095816
# PX095816
# PX095815 not in coord file
# PX095815
# PX095815 not in coord file
# PX095814 not in coord file
# PX095814 not in coord file
# PX095793
# PX095793 not in coord file
# PX095793
# PX095754 not in coord file
# PX095754 not in coord file
# PX095754 not in coord file
# PX095750 not in coord file
# PX095698 not in coord file
# PX095697 not in coord file
# PX095697
# PX095697 not in coord file
# PX095696 not in coord file
# PX095696
# PX095696 not in coord file
# PX095695
# PX095695 not in coord file
# PX095695 not in coord file
# PV975263 not in coord file
# PV975263 not in coord file
# PV975263 not in coord file
# PV975262 not in coord file
# PV975262 not in coord file
# PV975262 not in coord file
# PX113257 not in coord file
# PX113257 not in coord file
# PX113256 not in coord file
# PX113256 not in coord file
# PX113255 not in coord file
# PX113255 not in coord file
# PX113254 not in coord file
# PX113254 not in coord file
# PX113254 not in coord file
# PX113252 not in coord file
# PX113251 not in coord file
# PV067282 not in coord file
# PV067282 not in coord file
# PV999258 not in coord file
# PV999257 not in coord file
# PV999257 not in coord file
# PV999256 not in coord file
# PV999255 not in coord file
# PV979748
# PV979748
# PV979748 not in coord file
# PP980351 not in coord file
# PP980349 not in coord file
# PP980348 not in coord file
# PP980347 not in coord file
# PP980346 not in coord file
# PP980345 not in coord file
# PP980343 not in coord file
# PP980342 not in coord file
# PP980341 not in coord file
# PP980340 not in coord file
# PP980339 not in coord file
# PV972769 not in coord file
# PV972769 not in coord file
# PV972769 not in coord file
# PV972767 not in coord file
# PV972767 not in coord file
# PV972767 not in coord file
# PV972766 not in coord file
# PV972766 not in coord file
# PV972766 not in coord file
# PV972765 not in coord file
# PV972765 not in coord file
# PV972765 not in coord file
# PV972764 not in coord file
# PV972764 not in coord file
# PV972764 not in coord file
# PV972762 not in coord file
# PV972762 not in coord file
# PV972762 not in coord file
# PV983331 not in coord file
# PV983331
# PV983331 not in coord file
# PV793828 not in coord file
# PV793833 not in coord file
# PV793833 not in coord file
# PV793832 not in coord file
# PV793832 not in coord file
# PV793831 not in coord file
# PV793831 not in coord file
# PV793830 not in coord file
# PV793830 not in coord file
# PV880246 not in coord file
# PV880246 not in coord file
# PV880245 not in coord file
# PV880245 not in coord file
# PV880244 not in coord file
# PV880242 not in coord file
# PV880242 not in coord file
# PV880241 not in coord file
# PV880241 not in coord file
# PV880240 not in coord file
# PV880240 not in coord file
# PV880239 not in coord file
# PQ421854 not in coord file
# PQ421854 not in coord file
# PQ421854 not in coord file
# PQ421853 not in coord file
# PQ421853 not in coord file
# PQ421853 not in coord file
# PQ421852 not in coord file
# PQ421852 not in coord file
# PQ421852 not in coord file
# PQ421851 not in coord file
# PQ421851 not in coord file
# PQ421851 not in coord file
# PQ421850 not in coord file
# PQ421850 not in coord file
# PQ421849 not in coord file
# PQ421849 not in coord file
# PQ421848 not in coord file
# PQ421848 not in coord file
# PQ421848 not in coord file
# PQ421847 not in coord file
# PQ421847 not in coord file
# PQ421847 not in coord file
# PQ421846 not in coord file
# PQ421846 not in coord file
# PQ421846 not in coord file
# PQ421845 not in coord file
# PQ421845 not in coord file
# PQ421845 not in coord file
# PQ421844 not in coord file
# PQ421844 not in coord file
# PQ421844 not in coord file
# PQ421843 not in coord file
# PQ421843 not in coord file
# PQ421843 not in coord file
# PQ421842 not in coord file
# PQ421842 not in coord file
# PQ421842 not in coord file
# PQ421841 not in coord file
# PQ421841 not in coord file
# PQ421841 not in coord file
# PP942995 not in coord file
# PP942995 not in coord file
# PP942994 not in coord file
# PP942994 not in coord file
# PV847578 not in coord file
# PV847578 not in coord file
# PV843273 not in coord file
# PV838126 not in coord file
# PV838126 not in coord file
# PV838125 not in coord file
# PV838125 not in coord file
# PV838124 not in coord file
# PV838124 not in coord file
# PV838123 not in coord file
# PV838123 not in coord file
# PV838122 not in coord file
# PV838122 not in coord file
# PV838121 not in coord file
# PV838121 not in coord file
# PV838120 not in coord file
# PV838120 not in coord file
# PV838119 not in coord file
# PV838119 not in coord file
# PV838118 not in coord file
# PV838118 not in coord file
# PV838117 not in coord file
# PV838117 not in coord file
# PV838116 not in coord file
# PV838116 not in coord file
# PV838115 not in coord file
# PV838115 not in coord file
# PV838114 not in coord file
# PV838114 not in coord file
# PV838113 not in coord file
# PV838113 not in coord file
# PV838112 not in coord file
# PV838112 not in coord file
# PV838111 not in coord file
# PV838111 not in coord file
# PV838110 not in coord file
# PV838110 not in coord file
# PV838109 not in coord file
# PV838109 not in coord file
# PV838108 not in coord file
# PV838108 not in coord file
# PV838107 not in coord file
# PV838107 not in coord file
# PV838106 not in coord file
# PV838106 not in coord file
# PV838105 not in coord file
# PV838105 not in coord file
# PV838104 not in coord file
# PV838104 not in coord file
# PV838103 not in coord file
# PV838103 not in coord file
# PV838102 not in coord file
# PV838102 not in coord file
# PV838101 not in coord file
# PV838101 not in coord file
# PV838100 not in coord file
# PV838100 not in coord file
# PV838099 not in coord file
# PV838099 not in coord file
# PV838098 not in coord file
# PV838098 not in coord file
# PV838097 not in coord file
# PV838097 not in coord file
# PV838096 not in coord file
# PV838096 not in coord file
# PV838095 not in coord file
# PV838095 not in coord file
# PV838094 not in coord file
# PV838094 not in coord file
# PV838093 not in coord file
# PV838093 not in coord file
# PV791158 not in coord file
# PV791158 not in coord file
# PV780444 not in coord file
# PV780444 not in coord file
# PV780443 not in coord file
# PV780443 not in coord file
# PV780442 not in coord file
# PV780442 not in coord file
# PV780441 not in coord file
# PV780441 not in coord file
# PV780440 not in coord file
# PV780440 not in coord file
# PV780439 not in coord file
# PV780439 not in coord file
# PV780438 not in coord file
# PV780438 not in coord file
# OP556335 not in coord file
# PP872139 not in coord file
# PP872139 not in coord file
# PP872138 not in coord file
# PP872137 not in coord file
# PP872136 not in coord file
# PP872135 not in coord file
# PP872135 not in coord file
# PP872134 not in coord file
# PP872134 not in coord file
# PP872133 not in coord file
# PP872133 not in coord file
# PP872132 not in coord file
# PP872132 not in coord file
# PP872131 not in coord file
# PP872130 not in coord file
# PP872130 not in coord file
# PP872129 not in coord file
# PP872129 not in coord file
# PP872128 not in coord file
# PP872128 not in coord file
# PP872127 not in coord file
# PP872127 not in coord file
# PP872126 not in coord file
# PP872125 not in coord file
# PP872125 not in coord file
# PP872124 not in coord file
# PP872124 not in coord file
# PP872123 not in coord file
# PP872122 not in coord file
# PP872122 not in coord file
# PP872121 not in coord file
# PP872121 not in coord file
# PP872120 not in coord file
# PP872120 not in coord file
# PP872119 not in coord file
# PP872118 not in coord file
# PP872118 not in coord file
# PP872117 not in coord file
# PP872117 not in coord file
# PP872116 not in coord file
# PP872116 not in coord file
# PP872115 not in coord file
# PP872115 not in coord file
# PP872114 not in coord file
# PP872114 not in coord file
# PP872113 not in coord file
# PP872113 not in coord file
# PP872112 not in coord file
# PP872112 not in coord file
# PP872111 not in coord file
# PP872111 not in coord file
# PP872110 not in coord file
# PP872110 not in coord file
# PP872109 not in coord file
# PP872109 not in coord file
# PP872108 not in coord file
# PP872108 not in coord file
# PP872107 not in coord file
# PP872107 not in coord file
# PP872106 not in coord file
# PP872106 not in coord file
# PP872105 not in coord file
# PP872105 not in coord file
# PP872104 not in coord file
# PP872104 not in coord file
# PP872103 not in coord file
# PP872103 not in coord file
# PP872102 not in coord file
# PP872102 not in coord file
# PP872101 not in coord file
# PP872101 not in coord file
# PP872100 not in coord file
# PP872100 not in coord file
# PP872099 not in coord file
# PP872099 not in coord file
# PP872098 not in coord file
# PP872097 not in coord file
# PP872097 not in coord file
# PP872096 not in coord file
# PP872096 not in coord file
# PP872095 not in coord file
# PP872095 not in coord file
# PP872094 not in coord file
# PP872094 not in coord file
# PP872093 not in coord file
# PP872093 not in coord file
# PP872092 not in coord file
# PP872092 not in coord file
# PP872091 not in coord file
# PP872091 not in coord file
# PP872090 not in coord file
# PP872090 not in coord file
# PP872089 not in coord file
# PP872089 not in coord file
# PP872088 not in coord file
# PP872088 not in coord file
# PP872087 not in coord file
# PP872087 not in coord file
# PP872086 not in coord file
# PP872086 not in coord file
# PP872085 not in coord file
# PP872084 not in coord file
# PP872083 not in coord file
# PP872083 not in coord file
# PP872082 not in coord file
# PP872082 not in coord file
# PP872081 not in coord file
# PP872080 not in coord file
# PP872080 not in coord file
# PP872079 not in coord file
# PP872078 not in coord file
# PP872078 not in coord file
# PP872077 not in coord file
# PP872077 not in coord file
# PP872076 not in coord file
# PP872076 not in coord file
# PP872075 not in coord file
# PP872075 not in coord file
# PP872074 not in coord file
# PP872074 not in coord file
# PP872073 not in coord file
# PP872072 not in coord file
# PP872072 not in coord file
# PP872071 not in coord file
# PP872071 not in coord file
# PP872070 not in coord file
# PP872070 not in coord file
# PP872069 not in coord file
# PP872068 not in coord file
# PP872068 not in coord file
# PP872067 not in coord file
# PP872067 not in coord file
# PP872066 not in coord file
# PP872066 not in coord file
# PP872065 not in coord file
# PP872064 not in coord file
# PP872063 not in coord file
# PP872063 not in coord file
# PP872062 not in coord file
# PP872062 not in coord file
# PP872061 not in coord file
# PP872060 not in coord file
# PP872060 not in coord file
# PP872059 not in coord file
# PP872059 not in coord file
# PP872058 not in coord file
# PP872058 not in coord file
# PP872057 not in coord file
# PP872057 not in coord file
# PP872056 not in coord file
# PP872055 not in coord file
# PP872055 not in coord file
# PP872054 not in coord file
# PP872054 not in coord file
# PP872053 not in coord file
# PP872053 not in coord file
# PP872052 not in coord file
# PP872052 not in coord file
# PP872051 not in coord file
# PP872051 not in coord file
# PP872050 not in coord file
# PP872050 not in coord file
# PP872049 not in coord file
# PP872049 not in coord file
# PP872048 not in coord file
# PP872048 not in coord file
# PP872047 not in coord file
# PP872046 not in coord file
# PP872046 not in coord file
# PP872045 not in coord file
# PP872045 not in coord file
# PP872044 not in coord file
# PP872044 not in coord file
# PP872043 not in coord file
# PP872042 not in coord file
# PP872042 not in coord file
# PP872041 not in coord file
# PP872041 not in coord file
# PP872040 not in coord file
# PP872039 not in coord file
# PP872039 not in coord file
# PP872038 not in coord file
# PP872037 not in coord file
# PP872037 not in coord file
# PP872036 not in coord file
# PP872036 not in coord file
# PP872035 not in coord file
# PP872035 not in coord file
# PP872034 not in coord file
# PP872034 not in coord file
# PP872033 not in coord file
# PP872033 not in coord file
# PP872032 not in coord file
# PP872032 not in coord file
# PP872031 not in coord file
# PP872031 not in coord file
# PP872030 not in coord file
# PP872030 not in coord file
# PP872029 not in coord file
# PP872028 not in coord file
# PP872027 not in coord file
# PP872027 not in coord file
# PP872026 not in coord file
# PP872026 not in coord file
# PP872025 not in coord file
# PP872025 not in coord file
# PP872024 not in coord file
# PP872024 not in coord file
# PP872023 not in coord file
# PP872023 not in coord file
# PP872022 not in coord file
# PP872022 not in coord file
# PP872021 not in coord file
# PP872021 not in coord file
# PP872020 not in coord file
# PP872020 not in coord file
# PP872019 not in coord file
# PP872019 not in coord file
# PP872018 not in coord file
# PP872018 not in coord file
# PP872017 not in coord file
# PP872016 not in coord file
# PP872016 not in coord file
# PP872015 not in coord file
# PP872014 not in coord file
# PP872014 not in coord file
# PP872013 not in coord file
# PP872012 not in coord file
# PP872012 not in coord file
# PP872011 not in coord file
# PP872010 not in coord file
# PP872010 not in coord file
# PP872009 not in coord file
# PP872009 not in coord file
# PP872008 not in coord file
# PP872008 not in coord file
# PP872007 not in coord file
# PP872007 not in coord file
# PP872006 not in coord file
# PP872005 not in coord file
# PP872005 not in coord file
# PP872004 not in coord file
# PP872004 not in coord file
# PP872003 not in coord file
# PP872003 not in coord file
# PP872002 not in coord file
# PP872002 not in coord file
# PP872001 not in coord file
# PP872001 not in coord file
# PP872000 not in coord file
# PP871999 not in coord file
# PP871999 not in coord file
# PP871998 not in coord file
# PP871998 not in coord file
# PP871997 not in coord file
# PP871997 not in coord file
# PP871996 not in coord file
# PP871996 not in coord file
# PP871995 not in coord file
# PP871995 not in coord file
# PP871994 not in coord file
# PP871994 not in coord file
# PP871993 not in coord file
# PP871993 not in coord file
# PP871992 not in coord file
# PP871992 not in coord file
# PP871991 not in coord file
# PP871991 not in coord file
# PP871990 not in coord file
# PP871990 not in coord file
# PP871989 not in coord file
# PP871989 not in coord file
# PP871988 not in coord file
# PP871988 not in coord file
# PP871987 not in coord file
# PP871987 not in coord file
# PP871986 not in coord file
# PP871986 not in coord file
# PP871985 not in coord file
# PP871984 not in coord file
# PP871983 not in coord file
# PP871983 not in coord file
# PP871982 not in coord file
# PP871982 not in coord file
# PP871981 not in coord file
# PP871980 not in coord file
# PP871980 not in coord file
# PP871979 not in coord file
# PP871978 not in coord file
# PP871978 not in coord file
# PP871977 not in coord file
# PP871977 not in coord file
# PP871976 not in coord file
# PP871976 not in coord file
# PP871975 not in coord file
# PP871975 not in coord file
# PP871974 not in coord file
# PP871973 not in coord file
# PP871973 not in coord file
# PP871972 not in coord file
# PP871972 not in coord file
# PP871971 not in coord file
# PP871971 not in coord file
# PP871970 not in coord file
# PP871969 not in coord file
# PP871969 not in coord file
# PP871968 not in coord file
# PP871968 not in coord file
# PP871967 not in coord file
# PP871967 not in coord file
# PP871966 not in coord file
# PP871966 not in coord file
# PP871965 not in coord file
# PP871965 not in coord file
# PP871964 not in coord file
# PP871964 not in coord file
# PP871963 not in coord file
# PP871963 not in coord file
# PP871962 not in coord file
# PP871961 not in coord file
# PP871960 not in coord file
# PP871959 not in coord file
# PP871959 not in coord file
# PP871958 not in coord file
# PP871958 not in coord file
# PP871957 not in coord file
# PP871957 not in coord file
# PP871956 not in coord file
# PP871956 not in coord file
# PP871955 not in coord file
# PP871955 not in coord file
# PP871954 not in coord file
# PP871954 not in coord file
# PP871953 not in coord file
# PP871953 not in coord file
# PP871952 not in coord file
# PP871952 not in coord file
# PP871951 not in coord file
# PP871951 not in coord file
# PP871950 not in coord file
# PP871950 not in coord file
# PP871949 not in coord file
# PP871949 not in coord file
# PP871948 not in coord file
# PP871948 not in coord file
# PP871947 not in coord file
# PP871947 not in coord file
# PP871946 not in coord file
# PP871946 not in coord file
# PP871945 not in coord file
# PP871945 not in coord file
# PP871944 not in coord file
# PP871944 not in coord file
# PP871943 not in coord file
# PP871943 not in coord file
# PP871942 not in coord file
# PP871942 not in coord file
# PP871941 not in coord file
# PP871941 not in coord file
# PP871940 not in coord file
# PP871940 not in coord file
# PP871939 not in coord file
# PP871939 not in coord file
# PP871938 not in coord file
# PP871938 not in coord file
# PP871937 not in coord file
# PP871937 not in coord file
# PP871936 not in coord file
# PP871936 not in coord file
# PP871935 not in coord file
# PP871935 not in coord file
# PP871934 not in coord file
# PP871934 not in coord file
# PP871933 not in coord file
# PP871933 not in coord file
# PP871932 not in coord file
# PP871932 not in coord file
# PP871931 not in coord file
# PP871931 not in coord file
# PP871930 not in coord file
# PP871930 not in coord file
# PP871929 not in coord file
# PP871928 not in coord file
# PP871928 not in coord file
# PP871927 not in coord file
# PP871927 not in coord file
# PP871926 not in coord file
# PP871926 not in coord file
# PP871925 not in coord file
# PP871925 not in coord file
# PP871924 not in coord file
# PP871924 not in coord file
# PP871923 not in coord file
# PP871923 not in coord file
# PP871922 not in coord file
# PP871922 not in coord file
# PP871921 not in coord file
# PP871920 not in coord file
# PP871920 not in coord file
# PP871919 not in coord file
# PP871918 not in coord file
# PP871918 not in coord file
# PP871917 not in coord file
# PP871916 not in coord file
# PP871916 not in coord file
# PP871915 not in coord file
# PP871915 not in coord file
# PP871914 not in coord file
# PP871914 not in coord file
# PP871913 not in coord file
# PP871913 not in coord file
# PP871912 not in coord file
# PP871912 not in coord file
# PP871911 not in coord file
# PP871911 not in coord file
# PP871910 not in coord file
# PP871909 not in coord file
# PP871909 not in coord file
# PP871908 not in coord file
# PP871908 not in coord file
# PP871907 not in coord file
# PP871907 not in coord file
# PP871906 not in coord file
# PP871906 not in coord file
# PP871905 not in coord file
# PP871905 not in coord file
# PP871904 not in coord file
# PP871903 not in coord file
# PP871903 not in coord file
# PP871902 not in coord file
# PP871902 not in coord file
# PP871901 not in coord file
# PP871900 not in coord file
# PP871900 not in coord file
# PP871899 not in coord file
# PP871899 not in coord file
# PP871898 not in coord file
# PP871897 not in coord file
# PP871897 not in coord file
# PP871896 not in coord file
# PP871896 not in coord file
# PP871895 not in coord file
# PP871895 not in coord file
# PP871894 not in coord file
# PP871894 not in coord file
# PP871893 not in coord file
# PP871893 not in coord file
# PP871892 not in coord file
# PP871892 not in coord file
# PP871891 not in coord file
# PP871891 not in coord file
# PP871890 not in coord file
# PP871889 not in coord file
# PP871889 not in coord file
# PP871888 not in coord file
# PP871888 not in coord file
# PP871887 not in coord file
# PP871887 not in coord file
# PP871886 not in coord file
# PP871886 not in coord file
# PP871885 not in coord file
# PP871885 not in coord file
# PP871884 not in coord file
# PP871884 not in coord file
# PP871883 not in coord file
# PP871883 not in coord file
# PP871882 not in coord file
# PP871882 not in coord file
# PP871881 not in coord file
# PP871880 not in coord file
# PP871880 not in coord file
# PP871879 not in coord file
# PP871879 not in coord file
# PP871878 not in coord file
# PP871877 not in coord file
# PP871877 not in coord file
# PP871876 not in coord file
# PP871876 not in coord file
# PP871875 not in coord file
# PP871875 not in coord file
# PP871874 not in coord file
# PP871874 not in coord file
# PP871873 not in coord file
# PP871872 not in coord file
# PP871872 not in coord file
# PP871871 not in coord file
# PP871871 not in coord file
# PP871870 not in coord file
# PP871870 not in coord file
# PP871869 not in coord file
# PP871869 not in coord file
# PP871868 not in coord file
# PP871868 not in coord file
# PP871867 not in coord file
# PP871867 not in coord file
# PP871866 not in coord file
# PP871866 not in coord file
# PP871865 not in coord file
# PP871865 not in coord file
# PP871864 not in coord file
# PP871863 not in coord file
# PP871863 not in coord file
# PP871862 not in coord file
# PP871862 not in coord file
# PP871861 not in coord file
# PP871860 not in coord file
# PP871860 not in coord file
# PP871859 not in coord file
# PP871859 not in coord file
# PP871858 not in coord file
# PP871858 not in coord file
# PP871857 not in coord file
# PP871857 not in coord file
# PP871856 not in coord file
# PP871855 not in coord file
# PP871855 not in coord file
# PP871854 not in coord file
# PP871854 not in coord file
# PP871853 not in coord file
# PP871853 not in coord file
# PP871852 not in coord file
# PP871852 not in coord file
# PP871851 not in coord file
# PP871850 not in coord file
# PP871850 not in coord file
# PP871849 not in coord file
# PP871849 not in coord file
# PP871848 not in coord file
# PP871848 not in coord file
# PP871847 not in coord file
# PP871847 not in coord file
# PP871846 not in coord file
# PP871846 not in coord file
# PP871845 not in coord file
# PP871845 not in coord file
# PP871844 not in coord file
# PP871844 not in coord file
# PP871843 not in coord file
# PP871843 not in coord file
# PP871842 not in coord file
# PP871842 not in coord file
# PP871841 not in coord file
# PP871841 not in coord file
# PP871840 not in coord file
# PP871840 not in coord file
# PP871839 not in coord file
# PP871839 not in coord file
# PP871838 not in coord file
# PP871838 not in coord file
# PP871837 not in coord file
# PP871837 not in coord file
# PP871836 not in coord file
# PP871835 not in coord file
# PP871834 not in coord file
# PP871834 not in coord file
# PP871833 not in coord file
# PP871833 not in coord file
# PP871832 not in coord file
# PP871832 not in coord file
# PP871831 not in coord file
# PP871831 not in coord file
# PP871830 not in coord file
# PP871830 not in coord file
# PP871829 not in coord file
# PP871829 not in coord file
# PP871828 not in coord file
# PP871828 not in coord file
# PP871827 not in coord file
# PP871827 not in coord file
# PP871826 not in coord file
# PP871826 not in coord file
# PP871825 not in coord file
# PP871825 not in coord file
# PP871824 not in coord file
# PP871824 not in coord file
# PP871823 not in coord file
# PP871823 not in coord file
# PP871822 not in coord file
# PP871822 not in coord file
# PP871821 not in coord file
# PP871821 not in coord file
# PP871820 not in coord file
# PP871820 not in coord file
# PP871819 not in coord file
# PP871819 not in coord file
# PP871818 not in coord file
# PP871818 not in coord file
# PP871817 not in coord file
# PP871817 not in coord file
# PP871816 not in coord file
# PP871814 not in coord file
# PP871813 not in coord file
# PP871811 not in coord file
# PP871810 not in coord file
# PP871809 not in coord file
# PP871807 not in coord file
# PP871806 not in coord file
# PP871805 not in coord file
# PP871803 not in coord file
# PP871802 not in coord file
# PP871802 not in coord file
# PP871801 not in coord file
# PP871797 not in coord file
# PP871796 not in coord file
# PP871795 not in coord file
# PP871794 not in coord file
# PP871793 not in coord file
# PP871792 not in coord file
# PP871781 not in coord file
# PP871780 not in coord file
# PP871779 not in coord file
# PP871778 not in coord file
# PP871777 not in coord file
# PP871773 not in coord file
# PP871772 not in coord file
# PP871771 not in coord file
# PP871771 not in coord file
# PP871770 not in coord file
# PP871768 not in coord file
# PP871767 not in coord file
# PP871764 not in coord file
# PP871760 not in coord file
# PP871759 not in coord file
# PP871757 not in coord file
# PP871756 not in coord file
# PP871755 not in coord file
# PP871754 not in coord file
# PP871753 not in coord file
# PP871750 not in coord file
# PP871747 not in coord file
# PP871746 not in coord file
# PP871743 not in coord file
# PP871741 not in coord file
# PP871740 not in coord file
# PP871739 not in coord file
# PP871738 not in coord file
# PP871736 not in coord file
# PP871735 not in coord file
# PP871733 not in coord file
# PP871732 not in coord file
# PP871730 not in coord file
# PP871727 not in coord file
# PP871724 not in coord file
# PP871723 not in coord file
# PP871723 not in coord file
# PP871722 not in coord file
# PV076096 not in coord file
# PV076096 not in coord file
# PV076095 not in coord file
# PV076094 not in coord file
# PV470470 not in coord file
# PV470470 not in coord file
# LC877794 not in coord file
# LC877794 not in coord file
# LC877793 not in coord file
# LC877793 not in coord file
# PQ619424 not in coord file
# PQ619424 not in coord file
# PQ619423 not in coord file
# PQ619423 not in coord file
# PQ619422 not in coord file
# PQ619422 not in coord file
# PQ619421 not in coord file
# PQ619421 not in coord file
# PQ619420 not in coord file
# PQ619420 not in coord file
# PQ619419 not in coord file
# PQ619419 not in coord file
# PP211426 not in coord file
# PP211426 not in coord file
# PP211349 not in coord file
# PP211349 not in coord file
# PP211348 not in coord file
# PP211348 not in coord file
# PP211347 not in coord file
# PP211347 not in coord file
# PP211346 not in coord file
# PP211346 not in coord file
# PP211345 not in coord file
# PP211345 not in coord file
# PP211344 not in coord file
# PP211344 not in coord file
# PP211343 not in coord file
# PP211343 not in coord file
# PP211271 not in coord file
# PP211271 not in coord file
# PP211271 not in coord file
# PP211270 not in coord file
# PP211270 not in coord file
# PP211238 not in coord file
# PP211238 not in coord file
# PP211223 not in coord file
# PP211223 not in coord file
# PP211223 not in coord file
# PP211222 not in coord file
# PP211222 not in coord file
# PP211222 not in coord file
# PP211221 not in coord file
# PP211221 not in coord file
# PP211221 not in coord file
# PV602113 not in coord file
# PV602113 not in coord file
# PV590879 not in coord file
# PV590879 not in coord file
# PV590878 not in coord file
# PV590878 not in coord file
# PV590877 not in coord file
# PV590877 not in coord file
# PV590876 not in coord file
# PV590876 not in coord file
# PV568368 not in coord file
# PV568368 not in coord file
# PV568367 not in coord file
# PV568367 not in coord file
# PV568365 not in coord file
# PV568365 not in coord file
# PV568364 not in coord file
# PV568364 not in coord file
# PV568362 not in coord file
# PV568362 not in coord file
# PV568361 not in coord file
# PV568361 not in coord file
# PV568359 not in coord file
# PV568359 not in coord file
# PV568358 not in coord file
# PV568358 not in coord file
# PV568357 not in coord file
# PV568357 not in coord file
# PV568356 not in coord file
# PV568356 not in coord file
# PV568354 not in coord file
# PV568354 not in coord file
# PV568353 not in coord file
# PV568353 not in coord file
# PV568351 not in coord file
# PV568351 not in coord file
# PV568350 not in coord file
# PV568350 not in coord file
# PV548864 not in coord file
# PV548864 not in coord file
# PV548863 not in coord file
# PV548863 not in coord file
# PV351774
# PV351774
# PV351774 not in coord file
# PV351773 not in coord file
# PV351772
# PV351772
# PV351772 not in coord file
# PV351771 not in coord file
# PV351770 not in coord file
# PV455027 not in coord file
# PV017218 not in coord file
# PV017218 not in coord file
# PQ583783 not in coord file
# PQ583783 not in coord file
# PQ583782 not in coord file
# PQ583782 not in coord file
# FJ890355 not in coord file
# FJ890354 not in coord file
# FJ890353 not in coord file
# FJ890352 not in coord file
# FJ890351 not in coord file
# FJ571074 not in coord file
# FJ571074 not in coord file
# FJ571073 not in coord file
# FJ571073 not in coord file
# FJ571072 not in coord file
# FJ571072 not in coord file
# FJ571071 not in coord file
# FJ571071 not in coord file
# FJ571070 not in coord file
# FJ571070 not in coord file
# FJ571069 not in coord file
# FJ571069 not in coord file
# FJ571068 not in coord file
# FJ571067 not in coord file
# FJ571066 not in coord file
# FJ571065 not in coord file
# PQ408913 not in coord file
# PQ408913 not in coord file
# PQ408912 not in coord file
# PQ408912 not in coord file
# PQ408911 not in coord file
# PQ408911 not in coord file
# PQ408910 not in coord file
# PQ408910 not in coord file
# PQ408909 not in coord file
# PQ408909 not in coord file
# PQ408908 not in coord file
# PQ408908 not in coord file
# PQ408907 not in coord file
# PQ408907 not in coord file
# PQ408906 not in coord file
# PQ408906 not in coord file
# PQ408905 not in coord file
# PQ408905 not in coord file
# PQ408904 not in coord file
# PQ408904 not in coord file
# PV335595 not in coord file
# PV335595 not in coord file
# PV335595 not in coord file
# PV335594 not in coord file
# PV335594 not in coord file
# PV335594 not in coord file
# PV335593 not in coord file
# PV335593 not in coord file
# PV335593 not in coord file
# PV089611 not in coord file
# PV089611 not in coord file
# PV089610 not in coord file
# PV089610 not in coord file
# PV089609 not in coord file
# PV089609 not in coord file
# PV089617 not in coord file
# PV089617 not in coord file
# PV089616 not in coord file
# PV089616 not in coord file
# PV089615 not in coord file
# PV089615 not in coord file
# PV089608 not in coord file
# PV089608 not in coord file
# PV089607 not in coord file
# PV089607 not in coord file
# PV089606 not in coord file
# PV089606 not in coord file
# PV089605 not in coord file
# PV089605 not in coord file
# PV089604 not in coord file
# PV089604 not in coord file
# PV089603 not in coord file
# PV089603 not in coord file
# PV089620 not in coord file
# PV089620 not in coord file
# PV089619 not in coord file
# PV089619 not in coord file
# PV089618 not in coord file
# PV089618 not in coord file
# PV089614 not in coord file
# PV089614 not in coord file
# PV089613 not in coord file
# PV089613 not in coord file
# PV089612 not in coord file
# PV089612 not in coord file
# PV089602 not in coord file
# PV089602 not in coord file
# PV089601 not in coord file
# PV089601 not in coord file
# PV089600 not in coord file
# PV089600 not in coord file
# PV089599 not in coord file
# PV089599 not in coord file
# PV089598 not in coord file
# PV089598 not in coord file
# PV089597 not in coord file
# PV089597 not in coord file
# PQ789235 not in coord file
# PQ789235 not in coord file
# PQ789234 not in coord file
# PQ789234 not in coord file
# PQ789233 not in coord file
# PQ789233 not in coord file
# PP357251 not in coord file
# PP357251 not in coord file
# PP357250 not in coord file
# PP357250 not in coord file
# PP357249 not in coord file
# PP357249 not in coord file
# PV210984 not in coord file
# PV210984 not in coord file
# PV210983 not in coord file
# PV210983 not in coord file
# PV210982 not in coord file
# PV210982 not in coord file
# PV210981 not in coord file
# PV210981 not in coord file
# PV210980 not in coord file
# PV210980 not in coord file
# PV210979 not in coord file
# PV210979 not in coord file
# PV210978 not in coord file
# PV210978 not in coord file
# PV210977 not in coord file
# PV210977 not in coord file
# PV210976 not in coord file
# PV210976 not in coord file
# PV210975 not in coord file
# PV210975 not in coord file
# PV210974 not in coord file
# PV210974 not in coord file
# PV210973 not in coord file
# PV210973 not in coord file
# PV210972 not in coord file
# PV210972 not in coord file
# PV210971 not in coord file
# PV210971 not in coord file
# PV210970 not in coord file
# PV210970 not in coord file
# PV210969 not in coord file
# PV210969 not in coord file
# PQ899177 not in coord file
# PQ899177 not in coord file
# PQ899176 not in coord file
# PQ899176 not in coord file
# PQ899173 not in coord file
# PQ899173 not in coord file
# PQ899171 not in coord file
# PQ899171 not in coord file
# PQ541182 not in coord file
# PQ541182 not in coord file
# PQ541169 not in coord file
# PQ541169 not in coord file
# PQ788589 not in coord file
# PQ788589 not in coord file
# PQ150499 not in coord file
# PQ150499 not in coord file
# PQ150499 not in coord file
# PQ883185 not in coord file
# PQ883185 not in coord file
# PQ883184 not in coord file
# PQ883184 not in coord file
# PQ883183 not in coord file
# PQ883183 not in coord file
# PQ883182 not in coord file
# PQ883182 not in coord file
# PQ998994 not in coord file
# PQ998994 not in coord file
# PQ998993 not in coord file
# PQ998993 not in coord file
# PQ998992 not in coord file
# PQ998992 not in coord file
# PQ777147 not in coord file
# PQ777147 not in coord file
# PQ777147 not in coord file
# PQ777146 not in coord file
# PQ777146 not in coord file
# PQ777146 not in coord file
# PQ777145 not in coord file
# PQ777145 not in coord file
# PQ777145 not in coord file
# PQ777144 not in coord file
# PQ777144 not in coord file
# PQ777144 not in coord file
# PQ777143 not in coord file
# PQ777143 not in coord file
# PQ777143 not in coord file
# PQ777142 not in coord file
# PQ777142 not in coord file
# PQ777142 not in coord file
# PQ777141 not in coord file
# PQ777141 not in coord file
# PQ777141 not in coord file
# PQ777140 not in coord file
# PQ777140 not in coord file
# PQ777140 not in coord file
# PQ777139 not in coord file
# PQ777139 not in coord file
# PQ777139 not in coord file
# PQ777138 not in coord file
# PQ777138 not in coord file
# PQ777138 not in coord file
# PQ777137 not in coord file
# PQ777137 not in coord file
# PQ777137 not in coord file
# PQ777136 not in coord file
# PQ777136 not in coord file
# PQ777136 not in coord file
# PQ777135 not in coord file
# PQ777135 not in coord file
# PQ777135 not in coord file
# PQ777134 not in coord file
# PQ777134 not in coord file
# PQ777134 not in coord file
# PQ777133 not in coord file
# PQ777133 not in coord file
# PQ777133 not in coord file
# PQ777132 not in coord file
# PQ777132 not in coord file
# PQ777132 not in coord file
# PQ777131 not in coord file
# PQ777131 not in coord file
# PQ777131 not in coord file
# PQ777130 not in coord file
# PQ777130 not in coord file
# PQ777130 not in coord file
# PQ777129 not in coord file
# PQ777129 not in coord file
# PQ777129 not in coord file
# PQ777128 not in coord file
# PQ777128 not in coord file
# PQ777128 not in coord file
# PQ777127 not in coord file
# PQ777127 not in coord file
# PQ777127 not in coord file
# PQ777126 not in coord file
# PQ777126 not in coord file
# PQ777126 not in coord file
# PQ777125 not in coord file
# PQ777125 not in coord file
# PQ777125 not in coord file
# PQ777124 not in coord file
# PQ777124 not in coord file
# PQ777124 not in coord file
# PQ678099 not in coord file
# PQ678099 not in coord file
# PQ678014 not in coord file
# PQ678008 not in coord file
# PQ792210 not in coord file
# PQ628032 not in coord file
# PQ628032 not in coord file
# PQ628031 not in coord file
# PQ628031 not in coord file
# PQ862915 not in coord file
# PQ862915 not in coord file
# PQ862914 not in coord file
# PQ862914 not in coord file
# PQ862913 not in coord file
# PQ862913 not in coord file
# PQ862912 not in coord file
# PQ862912 not in coord file
# PQ862911 not in coord file
# PQ862911 not in coord file
# PQ615938 not in coord file
# PQ615938 not in coord file
# OR752625 not in coord file
# OR752625 not in coord file
# OR752624 not in coord file
# OR752624 not in coord file
# OR752623 not in coord file
# OR752623 not in coord file
# OR752622 not in coord file
# OR752622 not in coord file
# OR752621 not in coord file
# OR752621 not in coord file
# OR752620 not in coord file
# OR752620 not in coord file
# OR752619 not in coord file
# OR752619 not in coord file
# OR752618 not in coord file
# OR752618 not in coord file
# OR752617 not in coord file
# OR752617 not in coord file
# OR752616 not in coord file
# OR752616 not in coord file
# OR752615 not in coord file
# OR752615 not in coord file
# OR752614 not in coord file
# OR752614 not in coord file
# OR752613 not in coord file
# OR752613 not in coord file
# OR752612 not in coord file
# OR752612 not in coord file
# OR752611 not in coord file
# OR752611 not in coord file
# OR752610 not in coord file
# OR752610 not in coord file
# OR752609 not in coord file
# OR752609 not in coord file
# OR752608 not in coord file
# OR752608 not in coord file
# OR752607 not in coord file
# OR752607 not in coord file
# OR752606 not in coord file
# OR752606 not in coord file
# OR752605 not in coord file
# OR752605 not in coord file
# OR752604 not in coord file
# OR752604 not in coord file
# OR752603 not in coord file
# OR752603 not in coord file
# OR752602 not in coord file
# OR752602 not in coord file
# OR752601 not in coord file
# OR752601 not in coord file
# OR752600 not in coord file
# OR752600 not in coord file
# OR752599 not in coord file
# OR752599 not in coord file
# OR752598 not in coord file
# OR752598 not in coord file
# OR752597 not in coord file
# OR752597 not in coord file
# OR752596 not in coord file
# OR752596 not in coord file
# OR752595 not in coord file
# OR752595 not in coord file
# OR752594 not in coord file
# OR752594 not in coord file
# OR752593 not in coord file
# OR752593 not in coord file
# OR752592 not in coord file
# OR752592 not in coord file
# OR752591 not in coord file
# OR752591 not in coord file
# OR752590 not in coord file
# OR752590 not in coord file
# OR752589 not in coord file
# OR752589 not in coord file
# OR752588 not in coord file
# OR752588 not in coord file
# OR752587 not in coord file
# OR752587 not in coord file
# OR752586 not in coord file
# OR752586 not in coord file
# OR752585 not in coord file
# OR752585 not in coord file
# OR752584 not in coord file
# OR752584 not in coord file
# OR752583 not in coord file
# OR752583 not in coord file
# OR752582 not in coord file
# OR752582 not in coord file
# OR752581 not in coord file
# OR752581 not in coord file
# OR752580 not in coord file
# OR752580 not in coord file
# OR752579 not in coord file
# OR752579 not in coord file
# OR752578 not in coord file
# OR752578 not in coord file
# OR752577 not in coord file
# OR752577 not in coord file
# OR752576 not in coord file
# OR752576 not in coord file
# OR752575 not in coord file
# OR752575 not in coord file
# OR752574 not in coord file
# OR752574 not in coord file
# OR752573 not in coord file
# OR752573 not in coord file
# OR752572 not in coord file
# OR752572 not in coord file
# OR752571 not in coord file
# OR752571 not in coord file
# OR752570 not in coord file
# OR752570 not in coord file
# OR752569 not in coord file
# OR752569 not in coord file
# OR752568 not in coord file
# OR752568 not in coord file
# OR752567 not in coord file
# OR752567 not in coord file
# OR752566 not in coord file
# OR752566 not in coord file
# OR752565 not in coord file
# OR752565 not in coord file
# OR752564 not in coord file
# OR752564 not in coord file
# OR752563 not in coord file
# OR752563 not in coord file
# OR752562 not in coord file
# OR752562 not in coord file
# OR752561 not in coord file
# OR752561 not in coord file
# OR752560 not in coord file
# OR752560 not in coord file
# OR752559 not in coord file
# OR752559 not in coord file
# OR752558 not in coord file
# OR752558 not in coord file
# OR752557 not in coord file
# OR752557 not in coord file
# OR752556 not in coord file
# OR752556 not in coord file
# OR752555 not in coord file
# OR752555 not in coord file
# OR752554 not in coord file
# OR752554 not in coord file
# OR752553 not in coord file
# OR752553 not in coord file
# OR752552 not in coord file
# OR752552 not in coord file
# OR752551 not in coord file
# OR752551 not in coord file
# OR752550 not in coord file
# OR752550 not in coord file
# OR752549 not in coord file
# OR752549 not in coord file
# OR752548 not in coord file
# OR752548 not in coord file
# OR752547 not in coord file
# OR752547 not in coord file
# OR752546 not in coord file
# OR752546 not in coord file
# OR752545 not in coord file
# OR752545 not in coord file
# OR752544 not in coord file
# OR752544 not in coord file
# OR752543 not in coord file
# OR752543 not in coord file
# OR752542 not in coord file
# OR752542 not in coord file
# OR752541 not in coord file
# OR752541 not in coord file
# OR752540 not in coord file
# OR752540 not in coord file
# OR752539 not in coord file
# OR752539 not in coord file
# OR752538 not in coord file
# OR752538 not in coord file
# OR752537 not in coord file
# OR752537 not in coord file
# OR752536 not in coord file
# OR752536 not in coord file
# OR752535 not in coord file
# OR752535 not in coord file
# OR752534 not in coord file
# OR752534 not in coord file
# OR752533 not in coord file
# OR752533 not in coord file
# OR752532 not in coord file
# OR752532 not in coord file
# OR752531 not in coord file
# OR752531 not in coord file
# OR752530 not in coord file
# OR752530 not in coord file
# OR752529 not in coord file
# OR752529 not in coord file
# OR752528 not in coord file
# OR752528 not in coord file
# OR752527 not in coord file
# OR752527 not in coord file
# OR752526 not in coord file
# OR752526 not in coord file
# OR752525 not in coord file
# OR752525 not in coord file
# OR752524 not in coord file
# OR752524 not in coord file
# OR752523 not in coord file
# OR752523 not in coord file
# OR752522 not in coord file
# OR752522 not in coord file
# OR752521 not in coord file
# OR752521 not in coord file
# OR752520 not in coord file
# OR752520 not in coord file
# OR752519 not in coord file
# OR752519 not in coord file
# OR752518 not in coord file
# OR752518 not in coord file
# OR752517 not in coord file
# OR752517 not in coord file
# OR752516 not in coord file
# OR752516 not in coord file
# OR752515 not in coord file
# OR752515 not in coord file
# OR752514 not in coord file
# OR752514 not in coord file
# OR752513 not in coord file
# OR752513 not in coord file
# OR752512 not in coord file
# OR752512 not in coord file
# OR752511 not in coord file
# OR752511 not in coord file
# OR752510 not in coord file
# OR752510 not in coord file
# OR752509 not in coord file
# OR752509 not in coord file
# OR752508 not in coord file
# OR752508 not in coord file
# OR752507 not in coord file
# OR752507 not in coord file
# OR752506 not in coord file
# OR752506 not in coord file
# OR752505 not in coord file
# OR752505 not in coord file
# OR752504 not in coord file
# OR752504 not in coord file
# OR752503 not in coord file
# OR752503 not in coord file
# OR752502 not in coord file
# OR752502 not in coord file
# OR752501 not in coord file
# OR752501 not in coord file
# OR752500 not in coord file
# OR752500 not in coord file
# OR752499 not in coord file
# OR752499 not in coord file
# OR752498 not in coord file
# OR752498 not in coord file
# OR752497 not in coord file
# OR752497 not in coord file
# OR752496 not in coord file
# OR752496 not in coord file
# OR752495 not in coord file
# OR752495 not in coord file
# OR752494 not in coord file
# OR752494 not in coord file
# OR752493 not in coord file
# OR752493 not in coord file
# OR752492 not in coord file
# OR752492 not in coord file
# OR752491 not in coord file
# OR752491 not in coord file
# OR752490 not in coord file
# OR752490 not in coord file
# OR752489 not in coord file
# OR752489 not in coord file
# OR752488 not in coord file
# OR752488 not in coord file
# OR752487 not in coord file
# OR752487 not in coord file
# OR752486 not in coord file
# OR752486 not in coord file
# OR752485 not in coord file
# OR752485 not in coord file
# PQ601068 not in coord file
# PQ601068 not in coord file
# PQ601068 not in coord file
# PQ601067 not in coord file
# PQ601067 not in coord file
# PQ601067 not in coord file
# PQ539468 not in coord file
# PQ539468 not in coord file
# PQ539467 not in coord file
# PQ539467 not in coord file
# PQ573797 not in coord file
# PQ573797 not in coord file
# PQ573796 not in coord file
# PQ573796 not in coord file
# OQ835730 not in coord file
# OQ835730 not in coord file
# OQ835729 not in coord file
# OQ835729 not in coord file
# ...
# FJ940720 not in coord file
# JQ081297 not in coord file
# JQ081297 not in coord file
# JQ081297 not in coord file
# EU165348 not in coord file
# EU165348 not in coord file
# EU165347 not in coord file
# EU165347 not in coord file
# EU165346 not in coord file
# EU165346 not in coord file
# EU165345 not in coord file
# EU165345 not in coord file
# EU165344 not in coord file
# EU165344 not in coord file
# EU165343 not in coord file
# EU165343 not in coord file
# EU022556 not in coord file
# EU022556 not in coord file
# EU022555 not in coord file
# EU022555 not in coord file
# EU022554 not in coord file
# EU022554 not in coord file
# EU022553 not in coord file
# EU022553 not in coord file
# EU022552 not in coord file
# EU022552 not in coord file
# EU022551 not in coord file
# EU022551 not in coord file
# DQ381360 not in coord file
# DQ381360 not in coord file
# DQ381359 not in coord file
# DQ381359 not in coord file
# DQ381358 not in coord file
# DQ381358 not in coord file
# DQ381357 not in coord file
# DQ381357 not in coord file
# DQ381356 not in coord file
# DQ381356 not in coord file
# DQ381355 not in coord file
# DQ381355 not in coord file
# DQ381354 not in coord file
# DQ381354 not in coord file
# DQ381353 not in coord file
# DQ381353 not in coord file
# DQ381352 not in coord file
# DQ381352 not in coord file
# DQ381351 not in coord file
# DQ381351 not in coord file
# DQ381350 not in coord file
# DQ381350 not in coord file
# DQ381349 not in coord file
# DQ381349 not in coord file
# DQ381348 not in coord file
# DQ381348 not in coord file
# DQ381347 not in coord file
# DQ381347 not in coord file
# DQ381346 not in coord file
# DQ381346 not in coord file
# DQ381345 not in coord file
# DQ381345 not in coord file
# DQ381344 not in coord file
# DQ381344 not in coord file
# DQ381343 not in coord file
# DQ381343 not in coord file
# DQ381342 not in coord file
# DQ381342 not in coord file
# DQ381341 not in coord file
# DQ381341 not in coord file
# DQ381340 not in coord file
# DQ381340 not in coord file
# DQ381339 not in coord file
# DQ381339 not in coord file
# DQ381338 not in coord file
# DQ381338 not in coord file
# DQ381337 not in coord file
# DQ381337 not in coord file
# DQ381336 not in coord file
# DQ381336 not in coord file
# DQ381335 not in coord file
# DQ381335 not in coord file
# DQ381334 not in coord file
# DQ381334 not in coord file
# DQ381333 not in coord file
# DQ381333 not in coord file
# DQ381332 not in coord file
# DQ381332 not in coord file
# DQ381331 not in coord file
# DQ381331 not in coord file
# DQ381330 not in coord file
# DQ381330 not in coord file
# DQ381329 not in coord file
# DQ381329 not in coord file
# DQ381328 not in coord file
# DQ381328 not in coord file
# DQ381327 not in coord file
# DQ381327 not in coord file
# DQ381326 not in coord file
# DQ381326 not in coord file
# DQ381325 not in coord file
# DQ381325 not in coord file
# DQ381324 not in coord file
# DQ381324 not in coord file
# DQ381323 not in coord file
# DQ381323 not in coord file
# DQ381322 not in coord file
# DQ381322 not in coord file
# DQ381321 not in coord file
# DQ381321 not in coord file
# DQ381320 not in coord file
# DQ381320 not in coord file
# DQ381319 not in coord file
# DQ381319 not in coord file
# DQ381318 not in coord file
# DQ381318 not in coord file
# DQ381317 not in coord file
# DQ381317 not in coord file
# DQ381316 not in coord file
# DQ381316 not in coord file
# DQ381315 not in coord file
# DQ381315 not in coord file
# DQ381314 not in coord file
# DQ381314 not in coord file
# DQ381313 not in coord file
# DQ381313 not in coord file
# DQ381312 not in coord file
# DQ381312 not in coord file
# DQ381311 not in coord file
# DQ381311 not in coord file
# DQ381310 not in coord file
# DQ381310 not in coord file
# DQ381309 not in coord file
# DQ381309 not in coord file
# DQ381308 not in coord file
# DQ381308 not in coord file
# DQ381307 not in coord file
# DQ381307 not in coord file
# DQ381306 not in coord file
# DQ381306 not in coord file
# DQ381305 not in coord file
# DQ381305 not in coord file
# DQ381304 not in coord file
# DQ381304 not in coord file
# DQ381303 not in coord file
# DQ381303 not in coord file
# DQ381302 not in coord file
# DQ381302 not in coord file
# DQ381301 not in coord file
# DQ381301 not in coord file
# DQ381300 not in coord file
# DQ381300 not in coord file
# DQ381299 not in coord file
# DQ381299 not in coord file
# DQ381298 not in coord file
# DQ381298 not in coord file
# DQ381297 not in coord file
# DQ381297 not in coord file
# DQ381296 not in coord file
# DQ381296 not in coord file
# DQ381295 not in coord file
# DQ381295 not in coord file
# DQ381294 not in coord file
# DQ381294 not in coord file
# DQ381293 not in coord file
# DQ381293 not in coord file
# DQ381292 not in coord file
# DQ381292 not in coord file
# DQ381291 not in coord file
# DQ381291 not in coord file
# DQ381290 not in coord file
# DQ381290 not in coord file
# DQ381289 not in coord file
# DQ381289 not in coord file
# DQ381288 not in coord file
# DQ381288 not in coord file
# DQ381287 not in coord file
# DQ381287 not in coord file
# DQ381286 not in coord file
# DQ381286 not in coord file
# DQ381285 not in coord file
# DQ381285 not in coord file
# DQ381284 not in coord file
# DQ381284 not in coord file
# DQ381283 not in coord file
# DQ381283 not in coord file
# DQ381282 not in coord file
# DQ381282 not in coord file
# DQ322271 not in coord file
# DQ322271 not in coord file
# DQ322270 not in coord file
# DQ322270 not in coord file
# DQ322269 not in coord file
# DQ322269 not in coord file
# DQ322268 not in coord file
# DQ322268 not in coord file
# DQ322267 not in coord file
# DQ322267 not in coord file
# DQ322266 not in coord file
# DQ322266 not in coord file
# DQ322265 not in coord file
# DQ322265 not in coord file
# DQ322264 not in coord file
# DQ322264 not in coord file
# DQ322263 not in coord file
# DQ322263 not in coord file
# DQ322262 not in coord file
# DQ322262 not in coord file
# DQ322261 not in coord file
# DQ322261 not in coord file
# DQ322260 not in coord file
# DQ322260 not in coord file
# DQ322259 not in coord file
# DQ322259 not in coord file
# DQ322258 not in coord file
# DQ322258 not in coord file
# DQ322257 not in coord file
# DQ322257 not in coord file
# DQ322256 not in coord file
# DQ322256 not in coord file
# DQ322255 not in coord file
# DQ322255 not in coord file
# DQ071656 not in coord file
# DQ071656 not in coord file
# DQ071655 not in coord file
# DQ071655 not in coord file
# DQ071654 not in coord file
# DQ071654 not in coord file
# DQ071653 not in coord file
# DQ071653 not in coord file
# DQ071652 not in coord file
# DQ071652 not in coord file
# DQ071651 not in coord file
# DQ071651 not in coord file
# DQ071650 not in coord file
# DQ071650 not in coord file
# DQ071649 not in coord file
# DQ071649 not in coord file
# DQ071648 not in coord file
# DQ071648 not in coord file
# AF292077 not in coord file
# AF292076 not in coord file
# AF292075 not in coord file
# AF292074 not in coord file
# AF257226 not in coord file
# AF257226 not in coord file
# U49220 not in coord file
# U49220 not in coord file
# U49220 not in coord file
# U49219 not in coord file
# U49219 not in coord file
# U49219 not in coord file
# U49218 not in coord file
# U49218 not in coord file
# U49218 not in coord file
# U49217 not in coord file
# U49217 not in coord file
# U49217 not in coord file
# U49216 not in coord file
# U49216 not in coord file
# U49216 not in coord file
# U49215 not in coord file
# U49215 not in coord file
# U49215 not in coord file
# U49214 not in coord file
# U49214 not in coord file
# U49214 not in coord file
# U49213 not in coord file
# U49213 not in coord file
# U49213 not in coord file
# U49212 not in coord file
# U49212 not in coord file
# U49212 not in coord file
# L38508 not in coord file
# L38508 not in coord file
# L38508 not in coord file
# L38507 not in coord file
# L38507 not in coord file
# L38507 not in coord file
# L38506 not in coord file
# L38506 not in coord file
# L38506 not in coord file
# L38505 not in coord file
# L38505 not in coord file
# L38505 not in coord file
# L23512 not in coord file
# L23512 not in coord file
# L23512 not in coord file
# L23510 not in coord file
# L23510 not in coord file
# L23510 not in coord file
# L23509 not in coord file
# L23509 not in coord file
# L23509 not in coord file
# L08014 not in coord file
# L08014 not in coord file
# L08014 not in coord file
# M87668 not in coord file
# M87668 not in coord file
# M87668 not in coord file
# JA764511 not in coord file
# JA764511 not in coord file
# JA764511 not in coord file
# JA764509 not in coord file
# JA764509 not in coord file
# JA764509 not in coord file
# JA764507 not in coord file
# JA764507 not in coord file
# JA764507 not in coord file
# JA764505 not in coord file
# JA764505 not in coord file
# JA764505 not in coord file
# JA764495 not in coord file
# JA764495 not in coord file
# JA764495 not in coord file
# JA764493 not in coord file
# JA764493 not in coord file
# JA764493 not in coord file
# HQ396890 not in coord file
# HQ396890 not in coord file
# HQ396889 not in coord file
# HQ396889 not in coord file
# HQ396888 not in coord file
# HQ396888 not in coord file
# HQ396887 not in coord file
# HQ396887 not in coord file
# HQ396886 not in coord file
# HQ396886 not in coord file
# HQ396885 not in coord file
# HQ396885 not in coord file
# HQ396884 not in coord file
# HQ396884 not in coord file
# HQ396883 not in coord file
# HQ396883 not in coord file
# HQ396882 not in coord file
# HQ396882 not in coord file
# HQ396881 not in coord file
# HQ396881 not in coord file
# HQ396880 not in coord file
# HQ396880 not in coord file
# HV511037 not in coord file
# HV511037 not in coord file
# HV511037 not in coord file
# HQ330505 not in coord file
# HQ330505 not in coord file
# HQ330504 not in coord file
# HQ330504 not in coord file
# HQ330503 not in coord file
# HQ330503 not in coord file
# HQ330502 not in coord file
# HQ330502 not in coord file
# HQ330501 not in coord file
# HQ330501 not in coord file
# HQ330500 not in coord file
# HQ330500 not in coord file
# HQ330499 not in coord file
# HQ330499 not in coord file
# HQ330498 not in coord file
# HQ330498 not in coord file
# HQ330497 not in coord file
# HQ330497 not in coord file
# HQ330496 not in coord file
# HQ330496 not in coord file
# HQ330495 not in coord file
# HQ330495 not in coord file
# HQ330494 not in coord file
# HQ330494 not in coord file
# HQ330493 not in coord file
# HQ330493 not in coord file
# HQ330492 not in coord file
# HQ330492 not in coord file
# HQ330491 not in coord file
# HQ330491 not in coord file
# HQ330490 not in coord file
# HQ330490 not in coord file
# HQ330489 not in coord file
# HQ330489 not in coord file
# HQ330488 not in coord file
# HQ330488 not in coord file
# HQ330487 not in coord file
# HQ330487 not in coord file
# HQ330486 not in coord file
# HQ330486 not in coord file
# HQ330485 not in coord file
# HQ330485 not in coord file
# HQ330484 not in coord file
# HQ330484 not in coord file
# HQ330483 not in coord file
# HQ330483 not in coord file
# HQ330482 not in coord file
# HQ330482 not in coord file
# HQ330481 not in coord file
# HQ330481 not in coord file
# HQ330506 not in coord file
# HQ330506 not in coord file
# FJ160481 not in coord file
# FJ160481 not in coord file
# AY769616 not in coord file
# AY769616 not in coord file
# U15136 not in coord file
# U15136 not in coord file
# U15136 not in coord file
# L06802 not in coord file
# L06802 not in coord file
# L06802 not in coord file
# FV536969 not in coord file
# FV536969 not in coord file
# FV536969 not in coord file
# FV536968 not in coord file
# FV536968 not in coord file
# FV536968 not in coord file
# FV536967 not in coord file
# FV536967 not in coord file
# FV536967 not in coord file
# FV536966 not in coord file
# FV536966 not in coord file
# FV536966 not in coord file
# AF117209 not in coord file
# AF117209 not in coord file
# AY257977 not in coord file
# AY257977 not in coord file
# AY257977 not in coord file
# HC086778 not in coord file
# HC086778 not in coord file
# HC086778 not in coord file
# HC086792 not in coord file
# HC086792 not in coord file
# HC086792 not in coord file
# HC086790 not in coord file
# HC086790 not in coord file
# HC086790 not in coord file
# HC086788 not in coord file
# HC086788 not in coord file
# HC086788 not in coord file
# HC086786 not in coord file
# HC086786 not in coord file
# HC086786 not in coord file
# HC086784 not in coord file
# HC086784 not in coord file
# HC086784 not in coord file
# HC086782 not in coord file
# HC086782 not in coord file
# HC086782 not in coord file
# HC086780 not in coord file
# HC086780 not in coord file
# HC086780 not in coord file
# HC086776 not in coord file
# HC086776 not in coord file
# HC086776 not in coord file
# HC086774 not in coord file
# HC086774 not in coord file
# HC086774 not in coord file
# HC086770 not in coord file
# HC086770 not in coord file
# HC086770 not in coord file
# HC086767 not in coord file
# HC086767 not in coord file
# HC086767 not in coord file
# AY769615 not in coord file
# AY769615 not in coord file
# AB496913 not in coord file
# AB496913 not in coord file
# DQ630763 not in coord file
# DQ630763 not in coord file
# EF138831 not in coord file
# EF138831 not in coord file
# EF138830 not in coord file
# EF138830 not in coord file
# EF138829 not in coord file
# EF138829 not in coord file
# EF138828 not in coord file
# EF138828 not in coord file
# EF138827 not in coord file
# EF138827 not in coord file
# EF138826 not in coord file
# EF138826 not in coord file
# EF138825 not in coord file
# EF138825 not in coord file
# EF138824 not in coord file
# EF138824 not in coord file
# EF138823 not in coord file
# EF138823 not in coord file
# AB009985 not in coord file
# AB009985 not in coord file
# AB009984 not in coord file
# AB009984 not in coord file
# AB000300 not in coord file
# AB000300 not in coord file
# AB000299 not in coord file
# AB000299 not in coord file
# AB000298 not in coord file
# AB000298 not in coord file
# AB000297 not in coord file
# AB000297 not in coord file
# AB000296 not in coord file
# AB000296 not in coord file
# AB000295 not in coord file
# AB000295 not in coord file
# AB000294 not in coord file
# AB000294 not in coord file
# AB000293 not in coord file
# AB000293 not in coord file
# AB000292 not in coord file
# AB000292 not in coord file
# AB000291 not in coord file
# AB000291 not in coord file
# AB000290 not in coord file
# AB000290 not in coord file
# AB000289 not in coord file
# AB000289 not in coord file
# AB000288 not in coord file
# AB000288 not in coord file
# AB000287 not in coord file
# AB000287 not in coord file
# AB000286 not in coord file
# AB000286 not in coord file
# AB000285 not in coord file
# AB000285 not in coord file
# AB000284 not in coord file
# AB000284 not in coord file
# AB000283 not in coord file
# AB000283 not in coord file
# AB000301 not in coord file
# AB000301 not in coord file
# AB025812 not in coord file
# AB025812 not in coord file
# AB025811 not in coord file
# AB025811 not in coord file
# AB025810 not in coord file
# AB025810 not in coord file
# AB025809 not in coord file
# AB025809 not in coord file
# AB025808 not in coord file
# AB025808 not in coord file
# AB025807 not in coord file
# AB025807 not in coord file
# AB025806 not in coord file
# AB025806 not in coord file
# AB025805 not in coord file
# AB025805 not in coord file
# AB025804 not in coord file
# AB025804 not in coord file
# AB025803 not in coord file
# AB025803 not in coord file
# AB025802 not in coord file
# AB025802 not in coord file
# AB025801 not in coord file
# AB025801 not in coord file
# AB037274 not in coord file
# AB037274 not in coord file
# AB037273 not in coord file
# AB037273 not in coord file
# EF583300 not in coord file
# EF583300 not in coord file
# Z16420 not in coord file
# Z16420 not in coord file
# Z16420 not in coord file
# AB033998 not in coord file
# AB033998 not in coord file
# Z11682 not in coord file
# Z11682 not in coord file
# Z11682 not in coord file
# AB046864 not in coord file
# AB046864 not in coord file
# AJ620759 not in coord file
# AJ620759 not in coord file
# AJ620757 not in coord file
# AJ620757 not in coord file
# AJ620756 not in coord file
# AJ620756 not in coord file
# AJ620755 not in coord file
# AJ620755 not in coord file
# AJ620754 not in coord file
# AJ620754 not in coord file
# AJ620753 not in coord file
# AJ620753 not in coord file
# AJ620751 not in coord file
# AJ620751 not in coord file
# Z33883 not in coord file
# Z33883 not in coord file
# AB005257 not in coord file
# AB005257 not in coord file
# Y15938 not in coord file
# Y15938 not in coord file
# Y08632 not in coord file
# Y08632 not in coord file
# Y08633 not in coord file
# Y08633 not in coord file
# Y08631 not in coord file
# Y08631 not in coord file
# Y08629 not in coord file
# Y08629 not in coord file
# Y08628 not in coord file
# Y08628 not in coord file
# Z66541 not in coord file
# Z66541 not in coord file
# Z46658 not in coord file
# Z46658 not in coord file
# L13745 not in coord file
# L13745 not in coord file
# L13745 not in coord file
